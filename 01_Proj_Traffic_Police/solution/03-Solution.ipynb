# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1><p style="text-align: center;">Data Analysis with Python <br>Project - 1</p><h1> - Traffic Police Stops <img src="https://docs.google.com/uc?id=17CPCwi3_VvzcS87TOsh4_U8eExOhL6Ki" class="img-fluid" alt="CLRSWY" width="200" height="100">

# %% [markdown]
# Are you more likely to get arrested at a certain time of day? Are drug-related stops on the rise? In this chapter, you will answer these and other questions by analyzing the dataset visually, since plots can help you to understand trends in a way that examining the raw data cannot.

# %% [markdown]
# ## Calculating the hourly arrest rate

# %% [markdown]
# When a police officer stops a driver, a small percentage of those stops ends in an arrest. This is known as the **arrest rate**. In this exercise, you'll find out whether the arrest rate varies by time of day.
#
# First, you'll calculate the arrest rate across all stops. Then, you'll calculate the **hourly arrest rate** by using the ``hour`` attribute of the ``index``. The hour ranges from ``0`` to ``23``, in which:
#
# ``0 = midnight``<br>
# ``12 = noon`` <br>
# ``23 = 11 PM``

# %% [markdown]
# > Before starting your work in this section **repeat the steps which you did in the first chapter for preparing the data.** Continue to this chapter based on where you were in the end of the first chapter.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Take the mean of the ``is_arrested`` column to calculate the overall arrest rate.
# *   Group by the ``hour`` attribute of the ``DataFrame`` index to calculate the hourly arrest rate.
# *   Save the **hourly arrest rate** ``Series`` as a new object, ``hourly_arrest_rate``.

# %%
import pandas as pd
#ri = pd.read_csv('RI_cleaned.csv', nrows=50000)
ri = pd.read_csv('RI_cleaned.csv')
drop_columns=["state", "county_name", "county_fips", "fine_grained_location"]
ri.drop(drop_columns, axis='columns', inplace=True)
ri.dropna(subset=['driver_gender'], inplace=True)
ri['is_arrested'] = ri.is_arrested.astype('bool')
combined = ri.stop_date.str.cat(ri.stop_time, sep=' ')
ri['stop_datetime'] = pd.to_datetime(combined)
ri.drop(["stop_date", "stop_time"], axis='columns', inplace=True)
ri["date_time"]=ri.stop_datetime   #this column an additional one created by richard.
ri.set_index('stop_datetime', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-45512e8b268a> in <module>
#       1 import pandas as pd
#       2 #ri = pd.read_csv('RI_cleaned.csv', nrows=50000)
# ----> 3 ri = pd.read_csv('RI_cleaned.csv')
#       4 drop_columns=["state", "county_name", "county_fips", "fine_grained_location"]
#       5 ri.drop(drop_columns, axis='columns', inplace=True)
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
ri['is_arrested'] = ri.is_arrested.astype('bool')

combined = ri.stop_date.str.cat(ri.stop_time, sep=' ')
ri['stop_datetime'] = pd.to_datetime(combined)
ri.drop(["stop_date", "stop_time"], axis='columns', inplace=True)

ri["date_time"]=ri.stop_datetime

ri.set_index('stop_datetime', inplace=True)

# %%
ri.index.hour
# Out:
# Float64Index([ 1.0, 20.0, 11.0, 12.0,  1.0,  8.0,  8.0, 17.0, 23.0, 20.0,
#               ...
#                nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan],
#              dtype='float64', name='stop_datetime', length=509681)

# %%
ri = pd.read_csv("police.csv")
ri.head()
# Out:
# C:\Users\ilkca\anaconda3\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# ...

# %%
ri.is_arrested.mean()
# Out:
# 0.034545825287968575

# %%
ri.index.hour
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-ebb0383ba16f> in <module>
# ----> 1 ri.index.hour
#
# AttributeError: 'RangeIndex' object has no attribute 'hour'

# %%
ri['stop_datetime'] = pd.to_datetime(ri['stop_date'].str.cat(ri['stop_time'],sep=" "))
ri.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_type_raw  search_type contraband_found stop_outcome is_arrested  \
# ...

# %%
ri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509681 entries, 0 to 509680
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     509681 non-null  object
#  1   state                  509681 non-null  object
#  2   stop_date              509671 non-null  object
#  3   stop_time              509671 non-null  object
#  4   location_raw           509681 non-null  object
#  5   county_name            0 non-null       float64
#  6   county_fips            0 non-null       float64
#  7   fine_grained_location  0 non-null       float64
#  8   police_department      509671 non-null  object
#  9   driver_gender          480584 non-null  object
#  10  driver_age_raw         480632 non-null  float64
#  11  driver_age             478986 non-null  float64
#  12  driver_race_raw        480608 non-null  object
#  13  driver_race            480608 non-null  object
# ...

# %%
ri['combined'] = ri['stop_date'].str.cat(ri['stop_time'],sep=" ")
ri.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_type  contraband_found stop_outcome is_arrested stop_duration  \
# ...

# %%
combined = ri.stop_date.str.cat(ri.stop_time, sep=' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-a26b05601d9c> in <module>
# ----> 1 combined = ri.stop_date.str.cat(ri.stop_time, sep=' ')
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'stop_date'

# %%
ri.set_index('stop_datetime', inplace=True)
ri.index
# Out:
# DatetimeIndex(['2005-01-02 01:55:00', '2005-01-02 20:30:00',
#                '2005-01-04 11:30:00', '2005-01-04 12:55:00',
#                '2005-01-06 01:30:00', '2005-01-12 08:05:00',
#                '2005-01-18 08:15:00', '2005-01-18 17:13:00',
#                '2005-01-23 23:15:00', '2005-01-24 20:32:00',
#                ...
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT',
#                                'NaT',                 'NaT'],
#               dtype='datetime64[ns]', name='stop_datetime', length=509681, freq=None)

# %%
ri.index.hour
# Out:
# Float64Index([ 1.0, 20.0, 11.0, 12.0,  1.0,  8.0,  8.0, 17.0, 23.0, 20.0,
#               ...
#                nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan],
#              dtype='float64', name='stop_datetime', length=509681)

# %%
ri.is_arrested.dtype
# Out:
# dtype('bool')

# %%
ri['is_arrested']= ri.is_arrested.astype(bool) ### bool yap gruop ta saydirmak icin
ri.is_arrested.dtype
# Out:
# dtype('bool')

# %%
print(ri.groupby(ri.index.hour).is_arrested.mean()) # budaki valuelerin hepsi is_arrested tan geliyor.
# Out:
# stop_datetime
# 0.0     0.119693
# 1.0     0.148556
# 2.0     0.141099
# 3.0     0.133672
# 4.0     0.171027
# 5.0     0.132911
# 6.0     0.042369
# 7.0     0.055755
# 8.0     0.068730
# 9.0     0.071658
# 10.0    0.069411
# 11.0    0.073083
# 12.0    0.083757
# 13.0    0.079301
# 14.0    0.080323
# 15.0    0.080375
# 16.0    0.089049
# 17.0    0.102170
# 18.0    0.097704
# 19.0    0.083351
# 20.0    0.089661
# 21.0    0.148670
# 22.0    0.112783
# 23.0    0.106722
# Name: is_arrested, dtype: float64

# %%
hourly_arrest_rate = ri.groupby(ri.index.hour).is_arrested.mean()
hourly_arrest_rate
# Out:
# stop_datetime
# 0.0     0.119693
# 1.0     0.148556
# 2.0     0.141099
# 3.0     0.133672
# 4.0     0.171027
# 5.0     0.132911
# 6.0     0.042369
# 7.0     0.055755
# 8.0     0.068730
# 9.0     0.071658
# 10.0    0.069411
# 11.0    0.073083
# 12.0    0.083757
# 13.0    0.079301
# 14.0    0.080323
# 15.0    0.080375
# 16.0    0.089049
# 17.0    0.102170
# 18.0    0.097704
# 19.0    0.083351
# 20.0    0.089661
# 21.0    0.148670
# 22.0    0.112783
# 23.0    0.106722
# Name: is_arrested, dtype: float64

# %%
ri['stop_datetime'] = pd.to_datetime(combined)

# %%
ri["date_time"]=ri.stop_datetime

# %%
ri.date_time.head()
# Out:
# stop_datetime
# 2005-01-02 01:55:00   2005-01-02 01:55:00
# 2005-01-02 20:30:00   2005-01-02 20:30:00
# 2005-01-04 11:30:00   2005-01-04 11:30:00
# 2005-01-04 12:55:00   2005-01-04 12:55:00
# 2005-01-06 01:30:00   2005-01-06 01:30:00
# Name: date_time, dtype: datetime64[ns]

# %%
ri.date_time.dt.hour.values
# Out:
# array([ 1., 20., 11., ..., nan, nan, nan])

# %%
ri.shape
# Out:
# (509681, 27)

# %%
ri.index.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-837f354d21ff> in <module>
# ----> 1 ri.index.head()
#
# AttributeError: 'DatetimeIndex' object has no attribute 'head'

# %%
ri.stop_datetime.dt.hour.values
# Out:
# array([ 1., 20., 11., ..., nan, nan, nan])

# %%
ri.date_time.dt.weekday
# Out:
# stop_datetime
# 2005-01-02 01:55:00    6.0
# 2005-01-02 20:30:00    6.0
# 2005-01-04 11:30:00    1.0
# 2005-01-04 12:55:00    1.0
# 2005-01-06 01:30:00    3.0
#                       ...
# NaT                    NaN
# NaT                    NaN
# NaT                    NaN
# NaT                    NaN
# NaT                    NaN
# Name: date_time, Length: 509681, dtype: float64

# %%
ri.groupby(ri.date_time.dt.hour).is_arrested.mean()
# Out:
# date_time
# 0.0     0.119693
# 1.0     0.148556
# 2.0     0.141099
# 3.0     0.133672
# 4.0     0.171027
# 5.0     0.132911
# 6.0     0.042369
# 7.0     0.055755
# 8.0     0.068730
# 9.0     0.071658
# 10.0    0.069411
# 11.0    0.073083
# 12.0    0.083757
# 13.0    0.079301
# 14.0    0.080323
# 15.0    0.080375
# 16.0    0.089049
# 17.0    0.102170
# 18.0    0.097704
# 19.0    0.083351
# 20.0    0.089661
# 21.0    0.148670
# 22.0    0.112783
# 23.0    0.106722
# Name: is_arrested, dtype: float64

# %% [markdown]
# ***

# %% [markdown]
# ## Plotting the hourly arrest rate

# %% [markdown]
# You'll create a line plot from the ``hourly_arrest_rate`` object. A line plot is appropriate in this case because you're showing how a quantity changes over time.
#
# This plot should help you to spot some trends that may not have been obvious when examining the raw numbers!

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Import ``matplotlib.pyplot`` using the alias ``plt``.
# *   Create a **line plot** of ``hourly_arrest_rate`` using the ``.plot()`` method.
# *   Label the ``x-axis`` as ``'Hour'``, label the ``y-axis`` as ``'Arrest Rate'``, and title the plot ``'Arrest Rate by Time of Day'``.
# *   Display the plot using the ``.show()`` function.

# %%
import matplotlib.pyplot as plt

# %%
hourly_arrest_rate.plot()
plt.xlabel('Hour')
plt.ylabel('Arrest Rate')
plt.title('Arrest Rate by Time of Day')
hourly_arrest_rate.plot()

#plt.xticks(np.arange(24)) ### x ekseninde saatleri 24 olarak gorebiliriz ayalayarak.
#plt.xticks=range(0,24,1)

# Display the plot
plt.show()


#hourly_arrest_rate.plot(xlabel = "Hour", ylabel = "Arrested Rate", title = "Arrest Rate by Time of Day", kind = "line")

# %% [markdown]
# ***

# %% [markdown]
# ## Plotting drug-related stops

# %% [markdown]
# In a small portion of traffic stops, drugs are found in the vehicle during a search. You'll assess whether these **drug-related stops** are becoming more common over time.
#
# The Boolean column ``drugs_related_stop`` indicates whether drugs were found during a given stop. You'll calculate the **annual drug rate** by **resampling** this column, and then you'll use a line plot to visualize how the rate has changed over time.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Calculate the **annual rate** of drug-related stops by **resampling** the ``drugs_related_stop`` column (on the ``'A'`` frequency) and taking the mean.
# *   Save the annual drug rate ``Series`` as a new object, ``annual_drug_rate``.
# *   Create a line plot of ``annual_drug_rate`` using the ``.plot()`` method.
# *   Display the plot using the ``.show()`` function.

# %%
ri.head(2)
# Out:
#                                 id state location_raw  county_name  \
# stop_datetime
# 2005-01-02 01:55:00  RI-2005-00001    RI      Zone K1          NaN
# 2005-01-02 20:30:00  RI-2005-00002    RI      Zone X4          NaN
#
#                      county_fips  fine_grained_location police_department  \
# stop_datetime
# 2005-01-02 01:55:00          NaN                    NaN               600
# 2005-01-02 20:30:00          NaN                    NaN               500
#
#                     driver_gender  driver_age_raw  driver_age  ...  \
# stop_datetime                                                  ...
# 2005-01-02 01:55:00             M          1985.0        20.0  ...
# 2005-01-02 20:30:00             M          1987.0        18.0  ...
#
#                     contraband_found stop_outcome is_arrested stop_duration  \
# stop_datetime
# 2005-01-02 01:55:00            False     Citation       False      0-15 Min
# ...

# %%
ri.drugs_related_stop.value_counts() ### Uyusturucu sebebei ile durdurulma
# Out:
# False    504916
# True       4765
# Name: drugs_related_stop, dtype: int64

# %%
ri.drugs_related_stop.dtypes
# Out:
# dtype('bool')

# %%
ri.groupby(ri.index.year).drugs_related_stop.mean() ## 1. Yontem annual ile bulmak icin
# Out:
# stop_datetime
# 2005.0    0.007884
# 2006.0    0.006308
# 2007.0    0.007951
# 2008.0    0.007018
# 2009.0    0.009574
# 2010.0    0.009436
# 2011.0    0.010613
# 2012.0    0.009798
# 2013.0    0.011144
# 2014.0    0.012675
# 2015.0    0.010177
# Name: drugs_related_stop, dtype: float64

# %%
ri.drugs_related_stop.resample('A').mean() ## 2.Yontem 
####"A" da Annual yillik frequency olarak goruyoruz burda.
# Out:
# stop_datetime
# 2005-12-31    0.007884
# 2006-12-31    0.006308
# 2007-12-31    0.007951
# 2008-12-31    0.007018
# 2009-12-31    0.009574
# 2010-12-31    0.009436
# 2011-12-31    0.010613
# 2012-12-31    0.009798
# 2013-12-31    0.011144
# 2014-12-31    0.012675
# 2015-12-31    0.010177
# Name: drugs_related_stop, dtype: float64

# %%
ri.drugs_related_stop.resample('Q').mean()  ## Quarter 3 aylik halinde veriler
# Out:
# stop_datetime
# 2005-03-31    0.035714
# 2005-06-30    0.000000
# 2005-09-30    0.000000
# 2005-12-31    0.007905
# 2006-03-31    0.006462
# 2006-06-30    0.004560
# 2006-09-30    0.007187
# 2006-12-31    0.007053
# 2007-03-31    0.005396
# 2007-06-30    0.007718
# 2007-09-30    0.010406
# 2007-12-31    0.008724
# 2008-03-31    0.008051
# 2008-06-30    0.007297
# 2008-09-30    0.005953
# 2008-12-31    0.006856
# 2009-03-31    0.008444
# 2009-06-30    0.009655
# 2009-09-30    0.008689
# 2009-12-31    0.011939
# 2010-03-31    0.010599
# 2010-06-30    0.009165
# 2010-09-30    0.009597
# 2010-12-31    0.008143
# 2011-03-31    0.012238
# 2011-06-30    0.012646
# 2011-09-30    0.009265
# 2011-12-31    0.008868
# 2012-03-31    0.010383
# 2012-06-30    0.010539
# 2012-09-30    0.007674
# 2012-12-31    0.010512
# 2013-03-31    0.012470
# 2013-06-30    0.011252
# 2013-09-30    0.010656
# 2013-12-31    0.010195
# 2014-03-31    0.013178
# 2014-06-30    0.013402
# 2014-09-30    0.013251
# ...

# %%
ri.drugs_related_stop.resample('M').mean()
### Nisan ayinda hic olmamis uyusturucudan durdurma olmamis mesela aylik olarak burda
# Out:
# stop_datetime
# 2005-01-31    0.100000
# 2005-02-28    0.000000
# 2005-03-31    0.000000
# 2005-04-30    0.000000
# 2005-05-31    0.000000
#                 ...
# 2015-08-31    0.008995
# 2015-09-30    0.007860
# 2015-10-31    0.006189
# 2015-11-30    0.007094
# 2015-12-31    0.008523
# Name: drugs_related_stop, Length: 132, dtype: float64

# %%
annual_drug_rate = ri.drugs_related_stop.resample('A').mean()
annual_drug_rate
# Out:
# stop_datetime
# 2005-12-31    0.007884
# 2006-12-31    0.006308
# 2007-12-31    0.007951
# 2008-12-31    0.007018
# 2009-12-31    0.009574
# 2010-12-31    0.009436
# 2011-12-31    0.010613
# 2012-12-31    0.009798
# 2013-12-31    0.011144
# 2014-12-31    0.012675
# 2015-12-31    0.010177
# Name: drugs_related_stop, dtype: float64

# %%
annual_drug_rate.plot()

# %% [markdown]
# ***

# %% [markdown]
# ## Comparing drug and search rates (to be deleted)

# %% [markdown]
# As you saw in the last exercise, the rate of **drug-related stops** increased significantly between ``2005`` and ``2015``. You might hypothesize that the rate of vehicle searches was also increasing, which would have led to an increase in drug-related stops even if more drivers were not carrying drugs.
#
# You can test this hypothesis by calculating the annual search rate, and then plotting it against the annual drug rate. If the hypothesis is true, then you'll see both rates increasing over time.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Calculate the annual search rate by **resampling** the ``search_conducted`` column, and save the result as ``annual_search_rate``.
# *   Concatenate ``annual_drug_rate`` and ``annual_search_rate`` along the ``columns axis``, and save the result as ``annual``.
# *   Create subplots of the drug and search rates from the ``annual`` ``DataFrame``.
# *   Display the subplots.

# %%
ri.columns
# Out:
# Index(['id', 'state', 'location_raw', 'county_name', 'county_fips',
#        'fine_grained_location', 'police_department', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race_raw', 'driver_race',
#        'violation_raw', 'violation', 'search_conducted', 'search_type_raw',
#        'search_type', 'contraband_found', 'stop_outcome', 'is_arrested',
#        'stop_duration', 'out_of_state', 'drugs_related_stop', 'district',
#        'combined', 'date_time', 'stop_datetime'],
#       dtype='object')

# %%
ri.search_conducted.head()
# Out:
# stop_datetime
# 2005-01-02 01:55:00    False
# 2005-01-02 20:30:00    False
# 2005-01-04 11:30:00    False
# 2005-01-04 12:55:00    False
# 2005-01-06 01:30:00    False
# Name: search_conducted, dtype: object

# %%
ri.search_conducted.value_counts(dropna = False)
# Out:
# False    491909
# True      17762
# True         10
# Name: search_conducted, dtype: int64

# %%
ri.search_conducted.dtype
# Out:
# dtype('O')

# %%
ri["search_conducted"] = ri.search_conducted.astype("bool")
ri.search_conducted.dtype
# Out:
# dtype('bool')

# %%
ri.groupby(ri.index.year).search_conducted.mean()  ## Type degistirmeliyiz "object" i bool olmali.
# Out:
# stop_datetime
# 2005.0    0.049719
# 2006.0    0.035943
# 2007.0    0.039434
# 2008.0    0.036761
# 2009.0    0.045682
# 2010.0    0.039159
# 2011.0    0.035157
# 2012.0    0.030578
# 2013.0    0.027257
# 2014.0    0.029010
# 2015.0    0.026729
# Name: search_conducted, dtype: float64

# %%
annual_search_rate = ri.search_conducted.resample('A').mean() ###groupby(ri.index.year)==resample('A') ayni oluyor.
annual_search_rate
# Out:
# stop_datetime
# 2005-12-31    0.049719
# 2006-12-31    0.035943
# 2007-12-31    0.039434
# 2008-12-31    0.036761
# 2009-12-31    0.045682
# 2010-12-31    0.039159
# 2011-12-31    0.035157
# 2012-12-31    0.030578
# 2013-12-31    0.027257
# 2014-12-31    0.029010
# 2015-12-31    0.026729
# Name: search_conducted, dtype: float64

# %%
annual = pd.concat([annual_drug_rate, annual_search_rate], axis='columns')
annual
# Out:
#                drugs_related_stop  search_conducted
# stop_datetime
# 2005-12-31               0.007884          0.049719
# 2006-12-31               0.006308          0.035943
# 2007-12-31               0.007951          0.039434
# 2008-12-31               0.007018          0.036761
# 2009-12-31               0.009574          0.045682
# 2010-12-31               0.009436          0.039159
# 2011-12-31               0.010613          0.035157
# 2012-12-31               0.009798          0.030578
# 2013-12-31               0.011144          0.027257
# 2014-12-31               0.012675          0.029010
# 2015-12-31               0.010177          0.026729

# %%
annual.plot(subplots=True);
## sutunlarini ayri ayri line yaptirmak icin "subplots = True " yapiyoruz ve tek figurde goruyoruz.

# %% [markdown]
# ***

# %% [markdown]
# ## Tallying violations by district

# %% [markdown]
# The state of **Rhode Island** is broken into six police districts, also known as zones. How do the zones compare in terms of what violations are caught by police?
#
# In this exercise, you'll create a frequency table to determine how many violations of each type took place in each of the six zones. Then, you'll filter the table to focus on the ``"K"`` zones, which you'll examine further in the next exercise.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Create a ``frequency table`` from the ``district`` and ``violation`` columns using the ``pd.crosstab()`` function.
# *   Save the ``frequency table`` as a new object, ``all_zones``.
# *   Select rows ``'Zone K1'`` through ``'Zone K3'`` from ``all_zones`` using the ``.loc[]`` accessor.
# *   Save the smaller table as a new object, ``k_zones``.

# %%
ri.district.unique()
# Out:
# array(['Zone K1', 'Zone X4', 'Zone X1', 'Zone K3', 'Zone X3', 'Zone K2',
#        'Zone NA'], dtype=object)

# %%
ri.district.value_counts(dropna=False)
# Out:
# Zone X4    135349
# Zone K3    113784
# Zone K2    101403
# Zone X3     94058
# Zone K1     48362
# Zone X1     16715
# Zone NA        10
# Name: district, dtype: int64

# %%
ri.violation.unique()
# Out:
# array(['Speeding', nan, 'Equipment', 'Other', 'Moving violation',
#        'Registration/plates', 'Seat belt'], dtype=object)

# %%
ri.violation.value_counts(dropna=False)
# Out:
# Speeding               268744
# Moving violation        90234
# Equipment               61252
# NaN                     29073
# Other                   24221
# Registration/plates     19830
# Seat belt               16327
# Name: violation, dtype: int64

# %%
ri.district.value_counts(dropna=False)
# Out:
# Zone X4    135349
# Zone K3    113784
# Zone K2    101403
# Zone X3     94058
# Zone K1     48362
# Zone X1     16715
# Zone NA        10
# Name: district, dtype: int64

# %%
pd.crosstab(ri.district, ri.violation) ## Bize crosstab DataFrame veriyor sonucta.
# Out:
# violation  Equipment  Moving violation  Other  Registration/plates  Seat belt  \
# district
# Zone K1         3788              7130   1502                  628          1
# Zone K2        11285             16440   5103                 4056       2898
# Zone K3        12959             16218   3929                 3871       3660
# Zone X1         1725              3711    752                  192        451
# Zone X3        11520             17179   4070                 3532       4446
# Zone X4        19975             29556   8865                 7551       4871
#
# violation  Speeding
# district
# Zone K1       33068
# Zone K2       57500
# Zone K3       68238
# Zone X1        6393
# Zone X3       48690
# Zone X4       54855

# %% [markdown]
# ***

# %%
all_zones = pd.crosstab(ri.district, ri.violation)

# %%
all_zones.loc['Zone K1':'Zone K3']
# Out:
# violation  Equipment  Moving violation  Other  Registration/plates  Seat belt  \
# district
# Zone K1         3788              7130   1502                  628          1
# Zone K2        11285             16440   5103                 4056       2898
# Zone K3        12959             16218   3929                 3871       3660
#
# violation  Speeding
# district
# Zone K1       33068
# Zone K2       57500
# Zone K3       68238

# %%
k_zones = all_zones.loc['Zone K1':'Zone K3']
k_zones
# Out:
# violation  Equipment  Moving violation  Other  Registration/plates  Seat belt  \
# district
# Zone K1         3788              7130   1502                  628          1
# Zone K2        11285             16440   5103                 4056       2898
# Zone K3        12959             16218   3929                 3871       3660
#
# violation  Speeding
# district
# Zone K1       33068
# Zone K2       57500
# Zone K3       68238

# %% [markdown]
# ## Plotting violations by district

# %% [markdown]
# Now that you've created a frequency table focused on the ``"K"`` zones, you'll visualize the data to help you compare what violations are being caught in each zone.
#
# First you'll create a **bar plot**, which is an appropriate plot type since you're comparing categorical data. Then you'll create a **stacked bar plot** in order to get a slightly different look at the data. Which plot do you find to be more insightful?

# %% [markdown]
# **INSTRUCTIONS 1/2**
#
# *   Create a bar plot of ``k_zones``.
# *   Display the plot and examine it. What do you notice about each of the zones?

# %%
k_zones.plot(kind='bar')

plt.show()

# %% [markdown]
# **INSTRUCTIONS 2/2**
#
# *   Create a stacked bar plot of ``k_zones``.
# *   Display the plot and examine it. Do you notice anything different about the data than you did previously?

# %%
k_zones.plot(kind='bar', stacked=True)

# %%
#stack bar plot with oop
ax=k_zones.plot.bar(rot=0, stacked="True",figsize=(9,6))
ax.set_xlabel('Distincts')
ax.set_ylabel('Num of Violation')
ax.set_title('Violation by Distinct');

# %%
 #The vast majority of traffic stops in Zone K1 are for speeding, and Zones K2 and K3 are remarkably similar to one
    #another in terms of violations.

# %% [markdown]
# ***

# %% [markdown]
# ## Converting stop durations to numbers

# %% [markdown]
# In the traffic stops dataset, the ``stop_duration`` column tells you approximately how long the driver was detained by the officer. Unfortunately, the durations are stored as ``strings``, such as ``'0-15 Min'``. How can you make this data easier to analyze?
#
# In this exercise, you'll convert the **stop durations** to ``integers``. Because the precise durations are not available, you'll have to estimate the numbers using reasonable values:
#
# *   Convert ``'0-15 Min'`` to ``8``
# *   Convert ``'16-30 Min'`` to ``23``
# *   Convert ``'30+ Min'`` to ``45``

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Print the **unique values** in the ``stop_duration`` column. (This has been done for you.)
# *   Create a ``dictionary`` called ``mapping`` that maps the ``stop_duration`` strings to the integers specified above.
# *   Convert the ``stop_duration`` strings to integers using the ``mapping``, and store the results in a new column called ``stop_minutes``.
# *   Print the unique values in the ``stop_minutes`` column, to verify that the durations were properly converted to integers.

# %%
ri.stop_duration.head()
# Out:
# stop_datetime
# 2005-01-02 01:55:00     0-15 Min
# 2005-01-02 20:30:00    16-30 Min
# 2005-01-04 11:30:00          NaN
# 2005-01-04 12:55:00     0-15 Min
# 2005-01-06 01:30:00     0-15 Min
# Name: stop_duration, dtype: object

# %%
print(ri.stop_duration.unique())
['0-15 Min' '16-30 Min' '30+ Min']
# Out:
# ['0-15 Min' '16-30 Min' nan '30+ Min' '2' '1']
# ['0-15 Min16-30 Min30+ Min']

# %%
ri.stop_duration.value_counts(dropna = False) ## 1 saatlik durudrma 5 sefer, 2 saatlik durdurma 1 sefer olmus cok 
#gerekli degil bize o yuzden.
# Out:
# 0-15 Min     386665
# 16-30 Min     76323
# NaN           29073
# 30+ Min       17614
# 1                 5
# 2                 1
# Name: stop_duration, dtype: int64

# %%
mapping = {'0-15 Min':8, '16-30 Min':23, '30+ Min':45} ## COK ONEMLI MAPPING yapiyoruz, bir degisken yaptik kullanmak icin.

# %%
ri['stop_minutes'] = ri.stop_duration.map(mapping) ## Durdurma dakikalari.
#ri.stop_duration.apply(lambda x= mapping[x])

# %%
print(ri.stop_minutes.unique())
# Out:
# [ 8. 23. nan 45.]

# %%
ri.stop_minutes.value_counts(dropna=False)
# Out:
# 8.0     386665
# 23.0     76323
# NaN      29079
# 45.0     17614
# Name: stop_minutes, dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# ## Plotting stop length

# %% [raw]
# If you were stopped for a particular violation, how long might you expect to be detained?
#
# In this exercise, you'll visualize the **average length** of time drivers are stopped for each **type** of **violation**. Rather than using the ``violation`` column in this exercise, you'll use ``violation_raw`` since it contains more detailed descriptions of the violations.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   For each value in the ``violation_raw`` column, calculate the **mean number** of ``stop_minutes`` that a driver is detained.
# *   Save the resulting ``Series`` as a new object, ``stop_length``.
# *   Sort ``stop_length`` by its values, and then visualize it using a **horizontal bar plot**.
# *   Display the plot.

# %%
ri.violation_raw.unique()
# Out:
# array(['Speeding', nan, 'Equipment/Inspection Violation',
#        'Call for Service', 'Other Traffic Violation',
#        'Registration Violation', 'Violation of City/Town Ordinance',
#        'Special Detail/Directed Patrol', 'APB',
#        'Motorist Assist/Courtesy', 'Suspicious Person', 'Warrant',
#        'Seatbelt Violation'], dtype=object)

# %%
print(ri.groupby('violation_raw').stop_minutes.mean())
# Out:
# violation_raw
# APB                                 18.593814
# Call for Service                    21.967670
# Equipment/Inspection Violation      11.454213
# Motorist Assist/Courtesy            17.620202
# Other Traffic Violation             13.834137
# Registration Violation              13.543268
# Seatbelt Violation                   9.697924
# Special Detail/Directed Patrol      14.876778
# Speeding                            10.589193
# Suspicious Person                   18.374269
# Violation of City/Town Ordinance    13.230695
# Warrant                             19.769231
# Name: stop_minutes, dtype: float64

# %%
stop_length = ri.groupby('violation_raw').stop_minutes.mean()

# %%
#stop_length.sort_values().plot(kind='barh')
#Creating bar plot of stop_length DataFrame
ax = stop_length.plot.barh(rot=0, figsize=(10,7))
plt.title('Minutes Spent at Police Stop by Violation Type')
plt.xlabel('Minutes Spent')
plt.ylabel('Violation Type')
plt.show();

# %%
stop_length.sort_values().plot(kind='barh')
