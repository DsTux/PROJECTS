# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
#Indexle mede defeaoul index icin fazladan gelen index icin silmek istersek 
#ri =pd.read_csv("cleaned.csv", nrows=50000, index_col=0) kullaniyoruz.

# %%
df= pd.read_json("scout_car.json", lines = True)
df
#pd.read_json("scout_car.json", orient = "records", lines = True)
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# ...

# %%
df.shape
# Out:
# (15919, 54)

# %%
#pd.read_csv("ornekcsv.csv", sep = ";")

# %%
df.isnull().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# kW                               15919
# hp                                   0
# Type                                 2
# Previous Owners                   6640
# Next Inspection                  12384
# Inspection new                   11987
# Warranty                          5420
# Full Service                      7704
# Non-smoking Vehicle               8742
# null                                 0
# Make                                 0
# Model                                0
# Offer Number                      3175
# First Registration                1597
# Body Color                         597
# ...

# %%
df.isnull().sum()/ df.isnull().shape[0]*100
# Out:
# url                                0.000000
# make_model                         0.000000
# short_description                  0.288963
# body_type                          0.376908
# price                              0.000000
# vat                               28.349771
# km                                 0.000000
# registration                       0.000000
# prev_owner                        42.892141
# kW                               100.000000
# hp                                 0.000000
# Type                               0.012564
# Previous Owners                   41.711163
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Warranty                          34.047365
# Full Service                      48.395000
# Non-smoking Vehicle               54.915510
# null                               0.000000
# Make                               0.000000
# Model                              0.000000
# ...

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
def show_nans(df, limit):
    missing = df.isnull().sum()*100/df.shape[0]
    return missing.loc[lambda x : x > limit]
show_nans(df,70)
# Out:
# kW                               100.000000
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Emission Label                    74.967021
# Electricity consumption           99.139393
# Last Service Date                 96.444500
# Other Fuel Types                  94.472015
# Availability                      96.011056
# Last Timing Belt Service Date     99.899491
# Available from                    98.291350
# dtype: float64

# %%
df.drop(['kW', 'Next Inspection', 'Inspection new', 'Emission Label', 'Electricity consumption', 'Last Service Date', 'Other Fuel Types', 'Availability', 'Last Timing Belt Service Date', 'Available from'], axis='columns', inplace=True)

# %% [markdown]
# ### Displacement

# %%
import re
import pandas as pd

# %%
df['Displacement']
# Out:
# 0        [\n1,422 cc\n]
# 1        [\n1,798 cc\n]
# 2        [\n1,598 cc\n]
# 3        [\n1,422 cc\n]
# 4        [\n1,422 cc\n]
#               ...
# 15914    [\n1,997 cc\n]
# 15915    [\n1,798 cc\n]
# 15916    [\n1,997 cc\n]
# 15917    [\n1,997 cc\n]
# 15918    [\n1,798 cc\n]
# Name: Displacement, Length: 15919, dtype: object

# %%
df['Displacement']=df['Displacement'].str[0]
df['Displacement'].head()
# Out:
# 0    \n1,422 cc\n
# 1    \n1,798 cc\n
# 2    \n1,598 cc\n
# 3    \n1,422 cc\n
# 4    \n1,422 cc\n
# Name: Displacement, dtype: object

# %%
df['Displacement']=df['Displacement'].replace('[^0-9]','', regex=True)
df['Displacement'].head()
# Out:
# 0    1422
# 1    1798
# 2    1598
# 3    1422
# 4    1422
# Name: Displacement, dtype: object

# %%
def select(l):
    if l == "na":
        return np.nan
    return float(l[1])

# %%
pd.to_numeric(df["Displacement"].fillna("na").apply(select).str.strip("\n").str.rstrip(" cc").str.replace(",",""))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-664b2590b97f> in <module>
# ----> 1 pd.to_numeric(df["Displacement"].fillna("na").apply(select).str.strip("\n").str.rstrip(" cc").str.replace(",",""))
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-17-67ca07425506> in select(l)
#       2     if l == "na":
#       3         return np.nan
# ----> 4     return float(l[1])
#
# IndexError: string index out of range

# %%
#apply(lambda x: re.sub('\D',"",x))
#rakam harici tum karakterlerden kurtarabilirsiniz.

# %% [markdown]
# ### km

# %%
df["km"]
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914         - km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918         - km
# Name: km, Length: 15919, dtype: object

# %%
df["km"] =pd.to_numeric(df["km"].str.rstrip("km").str.replace(",",""),errors = "coerce").fillna(0)

# %%
df["km"]
# Out:
# 0        56013.0
# 1        80000.0
# 2        83450.0
# 3        73000.0
# 4        16200.0
#           ...
# 15914        0.0
# 15915     9900.0
# 15916       15.0
# 15917       10.0
# 15918        0.0
# Name: km, Length: 15919, dtype: float64

# %% [markdown]
# ### First Registration

# %%
def select(l):
    if l == "na":
        return np.nan
    return float(l[1])

# %%
clean =df["First Registration"].fillna("na").apply(select).describe()

clean["First Registration"] =df["First Registration"].fillna("na").apply(select)

# %%
df["First Registration"] = clean["First Registration"]
df["First Registration"]
# Out:
# 0        2016.0
# 1        2017.0
# 2        2016.0
# 3        2016.0
# 4        2016.0
#           ...
# 15914       NaN
# 15915    2019.0
# 15916    2019.0
# 15917    2019.0
# 15918    2019.0
# Name: First Registration, Length: 15919, dtype: float64

# %%
def coerce_m_columns_to_numeric(m, column_list):
    m[column_list] = m[column_list].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# ###### 2. Method

# %%
x= df["First Registration"]

# %%
x = "First Registration"

# %%
def n_sil(x):
    for i in range(0, len(x)):
        if isinstance(x[i], list):
            for a in x[i]:
                if a == "\n":
                    x[i].remove(a)
                elif "\n" in a:
                    x[i].remove(a)
                    b = a.replace("\n", "")
                    x[i].append(b)
        elif isinstance(x[i], str):
            x[i] = x[i].replace("\n", "")

# %%
for i in range(15919):
    df.loc[i, "year"] = 2020

# %%
def coerce_m_columns_to_numeric(df, column_list):
    df[column_list] = df[column_list].apply(pd.to_numeric, errors='coerce')

# %%
#df["Age"]=df["year"]-df["First Registration"]

# %% [markdown]
# ### 'Consumption'

# %%
df['Consumption'].head()
# Out:
# 0    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1    [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2    [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4    [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# Name: Consumption, dtype: object

# %%
df['Consumption'].str[1].str[0]
# Out:
# 0        4.3 l/100 km (city)
# 1        7.1 l/100 km (city)
# 2        4.4 l/100 km (city)
# 3        4.3 l/100 km (city)
# 4        4.6 l/100 km (city)
#                 ...
# 15914    6.2 l/100 km (city)
# 15915                      7
# 15916    6.2 l/100 km (city)
# 15917    6.2 l/100 km (city)
# 15918    8.7 l/100 km (city)
# Name: Consumption, Length: 15919, dtype: object

# %% [markdown]
# ### \nComfort & Convenience\n'

# %%
df["\nComfort & Convenience\n"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Air conditioning, Electrical side mirrors, Hill Holder, Power windows]                                                                                                                                                                                                                                                                                                                                             216
# ...

# %% [markdown]
# ### \nEntertainment & Media\n'

# %%
df['\nEntertainment & Media\n'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Bluetooth, Hands-free equipment, On-board computer, Radio, USB]                    1282
# [Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB]                982
# [Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB]     783
# [On-board computer, Radio]                                                           487
# ...

# %% [markdown]
# ### \nExtras\n'

# %%
df["\nExtras\n"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Alloy wheels]                                                                                              3245
# [Alloy wheels, Touch screen]                                                                                 697
# [Alloy wheels, Voice Control]                                                                                577
# ...

# %% [markdown]
# ### \nSafety & Security\n'

# %%
df["\nSafety & Security\n"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Fog lights, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control]                                                                                                                                                                                              538
# ...

# %% [markdown]
# ### Gears'

# %%
df["Gears"].str[0].str[1]
# Out:
# 0        NaN
# 1          7
# 2        NaN
# 3          6
# 4        NaN
#         ...
# 15914      6
# 15915      7
# 15916      6
# 15917      6
# 15918    NaN
# Name: Gears, Length: 15919, dtype: object

# %%
df["Gears"].str[0].str[1].value_counts()
# Out:
# 6    5822
# 5    3240
# 7    1908
# 8     224
# 9       6
# 4       2
# 3       2
# 1       2
# 2       1
# Name: Gears, dtype: int64

# %% [markdown]
# ### "Nr. of Doors"

# %%
df["Nr. of Doors"].str[0].str[1]
#df["Nr. of Doors"].str[0].strip("\n")
# Out:
# 0        5
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    5
# 15917    5
# 15918    5
# Name: Nr. of Doors, Length: 15919, dtype: object

# %%
#df["Nr. of Doors"].astype(float)
#df['Nr. of Doors'] = pd.to_numeric(df['Nr. of Doors'])

# %% [markdown]
# ### Country version

# %%
df["Country version"]
# Out:
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4        [\nGermany\n]
#              ...
# 15914              NaN
# 15915    [\nGermany\n]
# 15916    [\nAustria\n]
# 15917              NaN
# 15918    [\nGermany\n]
# Name: Country version, Length: 15919, dtype: object

# %%
df.groupby("body_type")['price'].mean()
# Out:
# body_type
# Compact          15216.240089
# Convertible      27905.375000
# Coupe            14222.720000
# Off-Road         17126.160714
# Other            14209.796552
# Sedans           17735.904846
# Station wagon    18643.281171
# Transporter      16764.795455
# Van              30846.632184
# Name: price, dtype: float64

# %%
df["body_type"].value_counts()
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
NaN ihtiva eden sütunları aynı marka-modelde olan diğer araçların mode'u ile dolduran fonksyion.
def fill_most(x, y):
    a = df[x][df['make_model'] == y].value_counts().index[0]
    b = df[x][df['make_model'] == y]
    b = b.apply(lambda z : z if isinstance(z, list) else a)
    df[x][df['make_model'] == y] = b
x = doldurmak istediğimiz sütun
y = marka-model ismi (edited)
# Out:
#   File "<ipython-input-13-9415d6b1dd46>", line 1
#     NaN ihtiva eden sütunları aynı marka-modelde olan diğer araçların mode'u ile dolduran fonksyion.
#              ^
# SyntaxError: invalid syntax

# %%
def unique_values(data, column_name):
    unique_vals = set()
    for rows in data[column_name]:
        unique_vals.update(rows)
    return list(unique_vals)

# %%
comfort sütunu için ilk önce nan değerleri doldurup, sonra string'e çevirip sonra da get_dummies ile 0-1 değerleriyle donatmanız gerekiyor
# Out:
#   File "<ipython-input-15-c40a5c108162>", line 1
#     comfort sütunu için ilk önce nan değerleri doldurup, sonra string'e çevirip sonra da get_dummies ile 0-1 değerleriyle donatmanız gerekiyor
#                  ^
# SyntaxError: invalid syntax

# %%
df["body_type][df["make_model"]==model] = df["body_type][df["make_model"]==model].fillna(mod)
return df["body_type][df["make_model"]==model]
# Out:
#   File "<ipython-input-16-c15fd77db481>", line 1
#     df["body_type][df["make_model"]==model] = df["body_type][df["make_model"]==model].fillna(mod)
#                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 'Consumption'

# %%
def try_join(l):
    try:
        return ','.join(map(str, set(l)))
    except TypeError:
        return np.nan

# %%
def n_sil(x):
    for i in range(0, len(x)):
        if isinstance(x[i], list):
            for a in x[i]:
                if a == "\n":
                    x[i].remove(a)
                elif "\n" in a:
                    x[i].remove(a)
                    b = a.replace("\n", "")
                    x[i].append(b)
        elif isinstance(x[i], str):
            x[i] = x[i].replace("\n", "")
Örnek = n_sil(df["Nr. of Seats"]), ... n_sil(df[i])
# Out:
#   File "<ipython-input-17-310db54f17fe>", line 13
#     Örnek = n_sil(df["Nr. of Seats"]), ... n_sil(df[i])
#                                                ^
# SyntaxError: invalid syntax

# %%
.strip()
# Out:
#   File "<ipython-input-18-a5e81a64f2bf>", line 1
#     .strip()
#     ^
# SyntaxError: invalid syntax

# %%
z = df["Consumption"].apply(lambda x: re.sub('\D',"",x))
z
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-167-9c0198d3c647> in <module>
# ----> 1 z = df["Consumption"].apply(lambda x: re.sub('\D',"",x))
#       2 z
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-167-9c0198d3c647> in <lambda>(x)
# ----> 1 z = df["Consumption"].apply(lambda x: re.sub('\D',"",x))
#       2 z
#
# ~\anaconda3\anaconda3\lib\re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
# ...

# %%
z.str.extract("(\d.\d*).+(\d.\d*).+(\d.\d*)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-8d9cb6095011> in <module>
# ----> 1 z.str.extract("(\d.\d*).+(\d.\d*).+(\d.\d*)")
#
# AttributeError: 'str' object has no attribute 'str'

# %%
data_cons = data["consumption"].str.strip("\n,").str.split(",",expand=True).reset_index(level=0).melt(id_vars='index',value_name='category_value').drop("variable",axis=1)
data_cons = data_cons.join(data_cons["category_value"].str.extract(r"(?P<consumption_amount>[\d|\.]+).*(?P<consumption_type>city|comb|country)",expand=True))
data_cons = data_cons.pivot_table(values=['consumption_amount'], index="index", columns=['consumption_type'], aggfunc='first')
data_cons = data_cons["consumption_amount"]
data_cons

# %%
ha bir de bu var listi string yapmak için
def try_join(l):
    try:
        return ','.join(map(str, set(l)))
    except TypeError:
        return np.nan

# %%
# nested sütunları one dimensional hale getirmek için böyle bir fonk yazdım bende

def consumption(x):
    if type(x) == list and type(x[0])==list :
        return x[0]+x[1]+x[2]
    elif type(x)==list and len(x)>3:
        return x

# %%
#df.explode("Type")

# %%
import re

# %%
df["Consumption"].head(3)
# Out:
# 0    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1    [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2    [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# Name: Consumption, dtype: object

# %%
def Clean_data(a): 
    # Search for opening bracket in the name followed by 
    # any characters repeated any number of times 
    if re.search('\,.*', a): 
  
        # Extract the position of beginning of pattern 
        pos = re.search('\,.*', a).start() 
  
        # return the cleaned name 
        return a[:pos] 
  
    else: 
        # if clean up needed return the same name 
        return a 
          
# Updated the city columns 
df['Consumption'] = df['Consumption'].apply(Clean_data) 
  
# Print the updated dataframe 
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-168-aa31173c1103> in <module>
#      15
#      16 # Updated the city columns
# ---> 17 df['Consumption'] = df['Consumption'].apply(Clean_data)
#      18
#      19 # Print the updated dataframe
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-168-aa31173c1103> in Clean_data(a)
#       2     # Search for opening bracket in the name followed by
#       3     # any characters repeated any number of times
# ...

# %%
df["Consumption"].str.strip('\n,')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-179-c3e5290d72bd> in <module>
# ----> 1 df["Consumption"].str.strip('\n,')
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...

# %% [markdown]
# ### "Nr. of Doors"

# %%
df["Nr. of Doors"]
# Out:
# 0        [\n5\n]
# 1        [\n3\n]
# 2        [\n4\n]
# 3        [\n3\n]
# 4        [\n5\n]
#           ...
# 15914    [\n5\n]
# 15915    [\n5\n]
# 15916    [\n5\n]
# 15917    [\n5\n]
# 15918    [\n5\n]
# Name: Nr. of Doors, Length: 15919, dtype: object

# %%
df["Nr. of Doors"].str[0].str[1]
# Out:
# 0        5
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    5
# 15917    5
# 15918    5
# Name: Nr. of Doors, Length: 15919, dtype: object

# %% [markdown]
# ## FUEL

# %%
cars['Fuel']=cars['Fuel'].str[1]  
cars.Fuel.loc[cars.Fuel.str.contains("Diesel")] == "Diesel"
cars.Fuel[cars.Fuel.str.contains('Diesel').isna()] = '5false5'
