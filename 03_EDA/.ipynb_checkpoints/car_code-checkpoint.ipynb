# %%
import numpy as np
import pandas as pd

# %%
#Indexle mede defeaoul index icin fazladan gelen index icin silmek istersek 
#ri =pd.read_csv("cleaned.csv", nrows=50000, index_col=0) kullaniyoruz.

# %%
df= pd.read_json("scout_car.json", lines = True)

# %%
pd.set_option('display.max_columns', None)
df.head(3)
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None NaN  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner NaN   85 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# ...

# %%
df.shape
# Out:
# (15919, 54)

# %%
df.hp
# Out:
# 0         66 kW
# 1        141 kW
# 2         85 kW
# 3         66 kW
# 4         66 kW
#           ...
# 15914    147 kW
# 15915    165 kW
# 15916    146 kW
# 15917    147 kW
# 15918    165 kW
# Name: hp, Length: 15919, dtype: object

# %%
df.isnull().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# kW                               15919
# hp                                   0
# Type                                 2
# Previous Owners                   6640
# Next Inspection                  12384
# Inspection new                   11987
# Warranty                          5420
# Full Service                      7704
# Non-smoking Vehicle               8742
# null                                 0
# Make                                 0
# Model                                0
# Offer Number                      3175
# First Registration                1597
# Body Color                         597
# ...

# %%
df.isnull().sum()/ df.isnull().shape[0]*100
# Out:
# url                                0.000000
# make_model                         0.000000
# short_description                  0.288963
# body_type                          0.376908
# price                              0.000000
# vat                               28.349771
# km                                 0.000000
# registration                       0.000000
# prev_owner                        42.892141
# kW                               100.000000
# hp                                 0.000000
# Type                               0.012564
# Previous Owners                   41.711163
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Warranty                          34.047365
# Full Service                      48.395000
# Non-smoking Vehicle               54.915510
# null                               0.000000
# Make                               0.000000
# Model                              0.000000
# ...

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
def show_nans(df, limit):
    missing = df.isnull().sum()*100/df.shape[0]
    return missing.loc[lambda x : x > limit]
show_nans(df,70)
# Out:
# kW                               100.000000
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Emission Label                    74.967021
# Electricity consumption           99.139393
# Last Service Date                 96.444500
# Other Fuel Types                  94.472015
# Availability                      96.011056
# Last Timing Belt Service Date     99.899491
# Available from                    98.291350
# dtype: float64

# %%
df.drop(['kW', 'Next Inspection', 'Inspection new', 'Emission Label', 'Electricity consumption', 'Last Service Date', 'Other Fuel Types', 'Availability', 'Last Timing Belt Service Date', 'Available from'], axis='columns', inplace=True)
df.head(20)
# Out:
#                                                   url make_model  \
# 0   https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1   https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2   https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3   https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4   https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 5   https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 6   https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 7   https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 8   https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 9   https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 10  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 11  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 12  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# ...

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'hp', 'Type', 'Previous Owners',
#        'Warranty', 'Full Service', 'Non-smoking Vehicle', 'null', 'Make',
#        'Model', 'Offer Number', 'First Registration', 'Body Color',
#        'Paint Type', 'Body Color Original', 'Upholstery', 'Body',
#        'Nr. of Doors', 'Nr. of Seats', 'Model Code', 'Gearing Type',
#        'Displacement', 'Cylinders', 'Weight', 'Drive chain', 'Fuel',
#        'Consumption', 'CO2 Emission', 'Emission Class',
#        '\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n',
#        '\nSafety & Security\n', 'description', 'Gears', 'Country version'],
#       dtype='object')

# %%
#df["Consumption"].str.extract("(\d.\d*).+(\d.\d*).+(\d.\d*)")

# %%
def try_join(l):
    try:
        return ','.join(map(str, set(l)))
    except TypeError:
        return np.nan

# %%
# nested sütunları one dimensional hale getirmek için böyle bir fonk yazdım bende

def consumption(x):
    if type(x) == list and type(x[0])==list :
        return x[0]+x[1]+x[2]
    elif type(x)==list and len(x)>3
        return x
# Out:
#   File "<ipython-input-312-bb2e5622debf>", line 3
#     def consumption('df.Consumption'):
#                                    ^
# SyntaxError: invalid syntax

# %%
#df.explode("Type")

# %%
import re

# %%
df["Consumption"].head(3)
# Out:
# 0    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1    [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2    [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# Name: Consumption, dtype: object

# %%
df.Consumption.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1        [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2        [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3        [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4        [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
#                                ...
# 15914    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915    [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918    [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
# Name: Consumption, Length: 15919, dtype: object>

# %%
def try_join(l):
    try:
        return ','.join(map(str, set(l)))
    except TypeError:
        return np.nan

# %%
l.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-297-e5b27f792679> in <module>
# ----> 1 l.dtype
#
# NameError: name 'l' is not defined

# %%
df.Consumption.shape
# Out:
# (15919,)

# %%
#df["Consumption"].str.exctract("(\d.\d).+(\d.\d).+(\d.\d).+(\d.\d).+(\d.\d)")

# %%
comb = df["Consumption"].str[0].str[0]
comb.head()
# Out:
# 0    3.8 l/100 km (comb)
# 1    5.6 l/100 km (comb)
# 2    3.8 l/100 km (comb)
# 3    3.8 l/100 km (comb)
# 4    4.1 l/100 km (comb)
# Name: Consumption, dtype: object

# %%
comb.tail(20)
# Out:
# 15899    5.3 l/100 km (comb)
# 15900    7.4 l/100 km (comb)
# 15901    5.1 l/100 km (comb)
# 15902    5.3 l/100 km (comb)
# 15903                    NaN
# 15904    5.3 l/100 km (comb)
# 15905    6.8 l/100 km (comb)
# 15906    7.4 l/100 km (comb)
# 15907                     \n
# 15908                    NaN
# 15909                    NaN
# 15910      6 l/100 km (comb)
# 15911    4.7 l/100 km (comb)
# 15912    5.3 l/100 km (comb)
# 15913    6.8 l/100 km (comb)
# 15914    5.3 l/100 km (comb)
# 15915                     \n
# 15916    5.3 l/100 km (comb)
# 15917    5.3 l/100 km (comb)
# 15918    6.8 l/100 km (comb)
# Name: Consumption, dtype: object

# %%
comb.shape
# Out:
# (15919,)

# %%
comb.value_counts()
# Out:
# \n                     850
# 3.9 l/100 km (comb)    732
# 4 l/100 km (comb)      712
# 5.4 l/100 km (comb)    662
# 5.1 l/100 km (comb)    627
#                       ...
# 7.5 l/100 km (comb)      1
# 1.2 l/100 km (comb)      1
# 50 l/100 km (comb)       1
# 1 l/100 km (comb)        1
# 55 l/100 km (comb)       1
# Name: Consumption, Length: 80, dtype: int64

# %%
comb_1 = comb.str.extract('(\d.\d|/d*)')
comb_1
# Out:
#          0
# 0      3.8
# 1      5.6
# 2      3.8
# 3      3.8
# 4      4.1
# ...    ...
# 15914  5.3
# 15915  NaN
# 15916  5.3
# 15917  5.3
# 15918  6.8
#
# [15919 rows x 1 columns]

# %%
comb_1.tail(20)
# Out:
#          0
# 15899  5.3
# 15900  7.4
# 15901  5.1
# 15902  5.3
# 15903  NaN
# 15904  5.3
# 15905  6.8
# 15906  7.4
# 15907  NaN
# 15908  NaN
# 15909  NaN
# 15910    /
# 15911  4.7
# 15912  5.3
# 15913  6.8
# 15914  5.3
# 15915  NaN
# 15916  5.3
# 15917  5.3
# 15918  6.8

# %%
city = df["Consumption"].str[1].str[0]
city.head()
# Out:
# 0    4.3 l/100 km (city)
# 1    7.1 l/100 km (city)
# 2    4.4 l/100 km (city)
# 3    4.3 l/100 km (city)
# 4    4.6 l/100 km (city)
# Name: Consumption, dtype: object

# %%
city_1 = city.str.extract('(\d.\d|/d*)')
city_1.head()
# Out:
#      0
# 0  4.3
# 1  7.1
# 2  4.4
# 3  4.3
# 4  4.6

# %%
city_1.shape
# Out:
# (15919, 1)

# %%
country = df["Consumption"].str[2].str[0]
country.head()
# Out:
# 0    3.5 l/100 km (country)
# 1    4.7 l/100 km (country)
# 2    3.4 l/100 km (country)
# 3    3.5 l/100 km (country)
# 4    3.8 l/100 km (country)
# Name: Consumption, dtype: object

# %%
country_1 = city.str.extract('(\d.\d|/d*)')
country_1.head()
# Out:
#      0
# 0  4.3
# 1  7.1
# 2  4.4
# 3  4.3
# 4  4.6

# %%
country_1.shape
# Out:
# (15919, 1)

# %%
comb_1.isnull().sum()
# Out:
# 0    2883
# dtype: int64

# %%
comb_1.isnull().sum()/ comb_1.isnull().shape[0]*100
# Out:
# 0    18.110434
# dtype: float64

# %%
city_1.isnull().sum()/ city_1.isnull().shape[0]*100
# Out:
# 0    20.554055
# dtype: float64

# %%
country_1.isnull().sum()/ country_1.isnull().shape[0]*100
# Out:
# 0    20.554055
# dtype: float64

# %%
Consumption_new = pd.concat([comb_1, city_1, country_1], axis = 0, ignore_index = True)

# %%
Consumption_new.columns
# Out:
# Int64Index([0], dtype='int64')

# %%
comb_1.values
# Out:
# array([['3.8'],
#        ['5.6'],
#        ['3.8'],
#        ...,
#        ['5.3'],
#        ['5.3'],
#        ['6.8']], dtype=object)

# %%
city_1.values
# Out:
# array([['4.3'],
#        ['7.1'],
#        ['4.4'],
#        ...,
#        ['6.2'],
#        ['6.2'],
#        ['8.7']], dtype=object)

# %%
country_1.values
# Out:
# array([['4.3'],
#        ['7.1'],
#        ['4.4'],
#        ...,
#        ['6.2'],
#        ['6.2'],
#        ['8.7']], dtype=object)

# %%
Consumption_new[[0,0,0]].rename(columns = {0:"comb", 0:"city", 0:"country"})
# Out:
#       country country country
# 0         3.8     3.8     3.8
# 1         5.6     5.6     5.6
# 2         3.8     3.8     3.8
# 3         3.8     3.8     3.8
# 4         4.1     4.1     4.1
# ...       ...     ...     ...
# 47752     6.2     6.2     6.2
# 47753     NaN     NaN     NaN
# 47754     6.2     6.2     6.2
# 47755     6.2     6.2     6.2
# 47756     8.7     8.7     8.7
#
# [47757 rows x 3 columns]

# %%
Consumption_new = pd.DataFrame({'comb':comb_1.values,'city':city_1.values,"country":country_1.values}, index=range(len(comb_1))
Consumption_new
# Out:
#   File "<ipython-input-246-3315e4c47265>", line 2
#     Consumption_new
#                   ^
# SyntaxError: invalid syntax

# %%
#df = pd.DataFrame({'income': income,'expense': expense, "profit": df.income - df.expense}, index=index)

#co_new[[0,1,2]].rename(columns = {0: "comb", 1: "city", 3: "country"})

# %%
#df["Consumption"] = df["Consumption"].str.strip('\n,')
df["Consumption"] = df["Consumption"].str.replace("\n,", "")

# %%
df["Consumption"].str.exctract("(\d.\d).+(\d.\d).+(\d.\d).+(\d.\d).+(\d.\d)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-249-2e49d423000d> in <module>
# ----> 1 df["Consumption"].str.exctract("(\d.\d).+(\d.\d).+(\d.\d).+(\d.\d).+(\d.\d)")
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...

# %%
consp[[0,1,3]].rename(columns = {0: "comb", 1:"city", 3:"country"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-250-a0a93deb3088> in <module>
# ----> 1 consp[[0,1,3]].rename(columns = {0: "comb", 1:"city", 3:"country"})
#
# NameError: name 'consp' is not defined

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'hp', 'Type', 'Previous Owners',
#        'Warranty', 'Full Service', 'Non-smoking Vehicle', 'null', 'Make',
#        'Model', 'Offer Number', 'First Registration', 'Body Color',
#        'Paint Type', 'Body Color Original', 'Upholstery', 'Body',
#        'Nr. of Doors', 'Nr. of Seats', 'Model Code', 'Gearing Type',
#        'Displacement', 'Cylinders', 'Weight', 'Drive chain', 'Fuel',
#        'Consumption', 'CO2 Emission', 'Emission Class',
#        '\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n',
#        '\nSafety & Security\n', 'description', 'Gears', 'Country version'],
#       dtype='object')

# %%
#df["Nr. of Doors"].astype(float)
#df['Nr. of Doors'] = pd.to_numeric(df['Nr. of Doors'])
df['Nr. of Doors']
# Out:
# 0        [\n5\n]
# 1        [\n3\n]
# 2        [\n4\n]
# 3        [\n3\n]
# 4        [\n5\n]
#           ...
# 15914    [\n5\n]
# 15915    [\n5\n]
# 15916    [\n5\n]
# 15917    [\n5\n]
# 15918    [\n5\n]
# Name: Nr. of Doors, Length: 15919, dtype: object

# %%
df["Nr. of Doors"].str[0].str[1]
#df["Nr. of Doors"].str[0].strip("\n")
# Out:
# 0        5
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    5
# 15917    5
# 15918    5
# Name: Nr. of Doors, Length: 15919, dtype: object

# %%
df['hp']
# Out:
# 0         66 kW
# 1        141 kW
# 2         85 kW
# 3         66 kW
# 4         66 kW
#           ...
# 15914    147 kW
# 15915    165 kW
# 15916    146 kW
# 15917    147 kW
# 15918    165 kW
# Name: hp, Length: 15919, dtype: object

# %%
for i in range(len(df['hp'])):
    df['hp'][i]= re.sub('[^0-9]','',df['hp'][i])
# Out:
# C:\Users\ilkca\anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.hp
# Out:
# 0         66
# 1        141
# 2         85
# 3         66
# 4         66
#         ...
# 15914    147
# 15915    165
# 15916    146
# 15917    147
# 15918    165
# Name: hp, Length: 15919, dtype: object

# %%
df["First Registration"]
# Out:
# 0        [\n, 2016, \n]
# 1        [\n, 2017, \n]
# 2        [\n, 2016, \n]
# 3        [\n, 2016, \n]
# 4        [\n, 2016, \n]
#               ...
# 15914               NaN
# 15915    [\n, 2019, \n]
# 15916    [\n, 2019, \n]
# 15917    [\n, 2019, \n]
# 15918    [\n, 2019, \n]
# Name: First Registration, Length: 15919, dtype: object

# %%
pd.read_csv("ornekcsv.csv", sep = ";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-258-514693d0b14d> in <module>
# ----> 1 pd.read_csv("ornekcsv.csv", sep = ";")
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df["First Registration"].strip("\n")

# %%
def n_sil('First Registration'):
    for i in range(0, len(['First Registration'])):
        if isinstance(First Registration[i], list):
            for a in First Registration[i]:
                if a == "\n":
                    First Registration[i].remove(a)
                elif "\n" in a:
                    First Registration[i].remove(a)
                    b = a.replace("\n", "")
                    First Registration[i].append(b)
        elif isinstance(First Registration[i], str):
            First Registration[i] = First Registration[i].replace("\n", "")
# Out:
#   File "<ipython-input-259-7bc62bdf8fc2>", line 1
#     def n_sil('First Registration'):
#                                  ^
# SyntaxError: invalid syntax

# %%
df["Displacement"].head(3)
# Out:
# 0    [\n1,422 cc\n]
# 1    [\n1,798 cc\n]
# 2    [\n1,598 cc\n]
# Name: Displacement, dtype: object

# %%
for i in range(len(df["Displacement"])):
    a = re.search('(\d*.\d*)',str(df.Displacement[i][0]))
    print(a.group())
# Out:
# 1,422
# 1,798
# 1,598
# 1,422
# 1,422
# 1,598
# 1,598
# 1,422
# 1,598
# 999
# 1,598
# 1,395
# 1,395
# 1,395
# 999
# 1,598
# 1,598
# 1,422
# 999
# 1,598
# 1,598
# 1,395
# 1,395
# 1,598
# 999
# 999
# 999
# 999
# 1,422
# 999
# 1,422
# 1,422
# 999
# 1,422
# 1,422
# 999
# 999
# 1,422
# 999
# 1,422
# 999
# 1,422
# 1,422
# 1,422
# 1,422
# 999
# 1,422
# 1,598
# 999
# 999
# 1,422
# 999
# 999
# 1,598
# 1,422
# 999
# 999
# 999
# 1,422
# 999
# 1,422
# 999
# 999
# 1,598
# 1,422
# 999
# 1,598
# 999
# 999
# 999
# 999
# 1,395
# 999
# 999
# 999
# 1,598
# 929
# 1,395
# 1,395
# 1,422
# 1,598
# 1,598
# 999
# 1,598
# 1,422
# 1,422
# 999
# 1,598
# 1,395
# 1,395
# 1,395
# 1,422
# 999
# 1,395
# 999
# 1,598
# 1,598
# 1,598
# 1,598
# 1,395
# 1,598
# 1,598
# 1,598
# 1,598
# 1,598
# 1,598
# 1,598
# 1,598
# 1,598
# 999
# 1,598
# 1,598
# 999
# 1,598
# 999
# 1,395
# 999
# 1,395
# 1,422
# 999
# 1,598
# 999
# 999
# 1,598
# 1,395
# 999
# 1,598
# 999
# 1,395
# 999
# 1,422
# 1,598
# 1,395
# 999
# 999
# 999
# 999
# 999
# ...

# %%
output = re.search('(\d*.\d*)', str(df.Displacement[1][0]))
print(output.group())
# Out:
# 1,798

# %%
import re
import pandas as pd

# %%
a = str(df.Displacement[0][0])
a
# Out:
# '\n1,422 cc\n'

# %%
a = str(df.Displacement[1][0])
a
# Out:
# '\n1,798 cc\n'

# %%
output = re.search('(\d*.\d*)', str(df.Displacement[1][0]))
print(output.group())
# Out:
# 1,798

# %%
map(lambda x: x * 2 , my_list)

# %%
df.Displacement.apply(lambda x: re.search('(\d*.\d*)', str(df.Displacement[x][0]),df.Displacement)
# Out:
#   File "<ipython-input-175-625385d80644>", line 1
#     df.Displacement.apply(lambda x: re.search('(\d*.\d*)', str(df.Displacement[x][0]),df.Displacement)
#                                                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
[for i in re.search('(\d*.\d*)', str(df.Displacement[i][0]):
   result
# Out:
#   File "<ipython-input-168-751ecd0ff662>", line 1
#     [for i in re.search('(\d*.\d*)', str(df.Displacement[i][0]):
#        ^
# SyntaxError: invalid syntax

# %%
df["Displacement"].str.extract(pat = '(/d*)')
# Out:
#          0
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
# [15919 rows x 1 columns]

# %%
def Clean_data(a): 
    # Search for opening bracket in the name followed by 
    # any characters repeated any number of times 
    if re.search('\,.*', a): 
  
        # Extract the position of beginning of pattern 
        pos = re.search('\,.*', a).start() 
  
        # return the cleaned name 
        return a[:pos] 
  
    else: 
        # if clean up needed return the same name 
        return a 
          
# Updated the city columns 
df['Displacement'] = df['Displacement'].apply(Clean_data) 
  
# Print the updated dataframe 
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-7574349acf30> in <module>
#      15
#      16 # Updated the city columns
# ---> 17 df['Displacement'] = df['Displacement'].apply(Clean_data)
#      18
#      19 # Print the updated dataframe
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-153-7574349acf30> in Clean_data(a)
#       2     # Search for opening bracket in the name followed by
#       3     # any characters repeated any number of times
# ...

# %%
s = pd.Series(df["Displacement"])
s
# Out:
# 0        [\n1,422 cc\n]
# 1        [\n1,798 cc\n]
# 2        [\n1,598 cc\n]
# 3        [\n1,422 cc\n]
# 4        [\n1,422 cc\n]
#               ...
# 15914    [\n1,997 cc\n]
# 15915    [\n1,798 cc\n]
# 15916    [\n1,997 cc\n]
# 15917    [\n1,997 cc\n]
# 15918    [\n1,798 cc\n]
# Name: Displacement, Length: 15919, dtype: object

# %%
df["Displacement"][150]
# Out:
# ['\n999 cc\n']

# %%
re.findall("\d*.\d*", a)
# Out:
# ['1,422', ' ', 'c', 'c']

# %%
output = re.search('(\d*.\d*)', a)
print(output.group())
# Out:
# 1,422

# %%
total_list = []
[for i in range(len(df.Displacement)):
    for re.search('(\d*.\d*)', df.Displacement[i]) in df.Displacement[i]:
        total_list.append(re.search('(\d*.\d*)', df.Displacement[i]))]
# Out:
#   File "<ipython-input-163-979c4cf30d15>", line 2
#     [for i in range(len(df.Displacement)):
#        ^
# SyntaxError: invalid syntax

# %%
a.str.extract('(\d).+(\d*)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-147-3e2704cfb6f4> in <module>
# ----> 1 a.str.extract('(\d).+(\d*)')
#
# AttributeError: 'str' object has no attribute 'str'

# %%
output.str.split(",")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-4d20e2bfca66> in <module>
# ----> 1 output.str.split(",")
#
# AttributeError: 're.Match' object has no attribute 'str'

# %%
(output.group()).apply(lambda x: x.split(","))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-9ed78c9b95f6> in <module>
# ----> 1 (output.group()).apply(lambda x: x.split(","))
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
(str(df.Displacement[0][0])).apply(lambda x: x.split("@")[1]).value_counts().head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-63e99c4dba70> in <module>
# ----> 1 (str(df.Displacement[0][0])).apply(lambda x: x.split("@")[1]).value_counts().head(5)
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
df["Displacement"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-2e2cdab42e7c> in <module>
# ----> 1 df["Displacement"].astype(int)
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
# ...

# %%
#df["Displacement"].str[0].str[1]
df["Displacement"].str[0].strip("\n")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-ab4fdaff7e80> in <module>
#       1 #df["Displacement"].str[0].str[1]
# ----> 2 df["Displacement"].str[0].strip("\n")
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strip'
