# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_info_columns', 500)
pd.set_option('display.max_info_rows', 2000)
pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.width', 2000)

# %%
#Indexle mede defeaoul index icin fazladan gelen index icin silmek istersek 
#ri =pd.read_csv("cleaned.csv", nrows=50000, index_col=0) kullaniyoruz.

# %% [markdown]
# ### Examine File

# %%
df= pd.read_json("scout_car.json", lines = True)

# %%
pd.set_option('display.max_columns', None)
df.head(3)
# Out:
#                                                                                                                                                 url make_model                                   short_description body_type  price               vat         km registration         prev_owner  kW      hp                                     Type Previous Owners                        Next Inspection         Inspection new                          Warranty Full Service Non-smoking Vehicle null      Make         Model     Offer Number First Registration       Body Color      Paint Type           Body Color Original          Upholstery              Body Nr. of Doors Nr. of Seats      Model Code         Gearing Type    Displacement Cylinders          Weight  Drive chain                                   Fuel                                                               Consumption               CO2 Emission Emission Class                                                                         
# ...

# %%
df.shape
# Out:
# (15919, 54)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   url                            object
#  1   make_model                     object
#  2   short_description              object
#  3   body_type                      object
#  4   price                          int64
#  5   vat                            object
#  6   km                             object
#  7   registration                   object
#  8   prev_owner                     object
#  9   kW                             float64
#  10  hp                             object
#  11  Type                           object
#  12  Previous Owners                object
#  13  Next Inspection                object
#  14  Inspection new                 object
#  15  Warranty                       object
#  16  Full Service                   object
# ...

# %%
df.describe() # we can see numeric values.
# Out:
#               price   kW
# count  15919.000000  0.0
# mean   18019.896727  NaN
# std     7386.169409  NaN
# min       13.000000  NaN
# 25%    12850.000000  NaN
# 50%    16900.000000  NaN
# 75%    21900.000000  NaN
# max    74600.000000  NaN

# %% [markdown]
# ### Handling with Missing Values.

# %%
df.shape[0]
# Out:
# 15919

# %%
df.isnull().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# kW                               15919
# hp                                   0
# Type                                 2
# Previous Owners                   6640
# Next Inspection                  12384
# Inspection new                   11987
# Warranty                          5420
# Full Service                      7704
# Non-smoking Vehicle               8742
# null                                 0
# Make                                 0
# Model                                0
# Offer Number                      3175
# First Registration                1597
# Body Color                         597
# ...

# %% [markdown]
# **before hangling missing values I recognize the data set

# %%
df.isnull().sum()/ df.isnull().shape[0]*100 # we can see the missing values.
#(oto.isnull().sum()/oto.shape[0]*100).sort_values(ascending =False)
# Out:
# url                                0.000000
# make_model                         0.000000
# short_description                  0.288963
# body_type                          0.376908
# price                              0.000000
# vat                               28.349771
# km                                 0.000000
# registration                       0.000000
# prev_owner                        42.892141
# kW                               100.000000
# hp                                 0.000000
# Type                               0.012564
# Previous Owners                   41.711163
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Warranty                          34.047365
# Full Service                      48.395000
# Non-smoking Vehicle               54.915510
# null                               0.000000
# Make                               0.000000
# Model                              0.000000
# ...

# %%
call_list = list(df.columns) #We can call columns as a list easily. All values are "string" in list.
call_list
#df.columns
# Out:
# ['url',
#  'make_model',
#  'short_description',
#  'body_type',
#  'price',
#  'vat',
#  'km',
#  'registration',
#  'prev_owner',
#  'kW',
#  'hp',
#  'Type',
#  'Previous Owners',
#  'Next Inspection',
#  'Inspection new',
#  'Warranty',
#  'Full Service',
#  'Non-smoking Vehicle',
#  'null',
#  'Make',
#  'Model',
#  'Offer Number',
#  'First Registration',
#  'Body Color',
#  'Paint Type',
#  'Body Color Original',
#  'Upholstery',
#  'Body',
#  'Nr. of Doors',
#  'Nr. of Seats',
#  'Model Code',
#  'Gearing Type',
#  'Displacement',
#  'Cylinders',
#  'Weight',
#  'Drive chain',
#  'Fuel',
#  'Consumption',
#  'CO2 Emission',
#  'Emission Class',
#  '\nComfort & Convenience\n',
#  '\nEntertainment & Media\n',
#  '\nExtras\n',
#  '\nSafety & Security\n',
#  'description',
#  'Emission Label',
#  'Gears',
#  'Country version',
#  'Electricity consumption',
#  'Last Service Date',
#  'Other Fuel Types',
#  'Availability',
#  'Last Timing Belt Service Date',
#  'Available from']

# %%
# We can choose the limit and run the code.

def show_nans(df, limit):
    missing = df.isnull().sum()*100/df.shape[0]
    return missing.loc[lambda x : x > limit]
show_nans(df,35)
# Out:
# prev_owner                        42.892141
# kW                               100.000000
# Previous Owners                   41.711163
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Full Service                      48.395000
# Non-smoking Vehicle               54.915510
# Paint Type                        36.258559
# Model Code                        68.729192
# Cylinders                         35.680633
# Weight                            43.809285
# Drive chain                       43.080596
# Emission Label                    74.967021
# Country version                   52.346253
# Electricity consumption           99.139393
# Last Service Date                 96.444500
# Other Fuel Types                  94.472015
# Availability                      96.011056
# Last Timing Belt Service Date     99.899491
# Available from                    98.291350
# dtype: float64

# %%
drop_list1 =( ['kW', 'Next Inspection', 'Inspection new', 'Emission Label', 'Electricity consumption', 'Last Service Date', 'Other Fuel Types', 'Availability', 'Last Timing Belt Service Date', 'Available from'])

# %%
df.drop(drop_list1, axis='columns', inplace=True)

# %% [markdown]
# ### "prev_owner" and "Previous Owners"¶

# %% [markdown]
# pip install pandas-profiling
# import pandas_profiling
# pandas_profiling.ProfileReport(oto)
# Burda ayrintili bilgi alabiliriz.

# %% [markdown]
# ### **General formul to remove '/n'

# %% [markdown]
# def n_sil(x):
#     for i in range(0, len(x)):
#         if isinstance(x[i], list):
#             for a in x[i]:
#                 if a == "\n":
#                     x[i].remove(a)
#                 elif "\n" in a:
#                     x[i].remove(a)
#                     b = a.replace("\n", "")
#                     x[i].append(b)
#         elif isinstance(x[i], str):
#             x[i] = x[i].replace("\n", "")

# %% [markdown]
# ### **body type

# %%
df[["prev_owner", "Previous Owners"]]
# Out:
#               prev_owner                                                                            Previous Owners
# 0      2 previous owners                                                                                      \n2\n
# 1                   None                                                                                        NaN
# 2       1 previous owner                                                                                      \n1\n
# 3       1 previous owner                                                                                      \n1\n
# 4       1 previous owner                                                                                      \n1\n
# ...                  ...                                                                                        ...
# 15914               None                                                                                        NaN
# ...

# %% [markdown]
# ### similar to each other

# %%
df["Previous Owners"]
# Out:
# 0                                                                                            \n2\n
# 1                                                                                              NaN
# 2                                                                                            \n1\n
# 3                                                                                            \n1\n
# 4                                                                                            \n1\n
#                                                    ...
# 15914                                                                                          NaN
# 15915    [\n1\n, \n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (city), \n, 6.3 l/100 km (country), \n]
# 15916                                                             [\n1\n, \n139 g CO2/km (comb)\n]
# 15917                                                                                          NaN
# ...

# %%
df['prev_owner']
# Out:
# 0        2 previous owners
# 1                     None
# 2         1 previous owner
# 3         1 previous owner
# 4         1 previous owner
#                ...
# 15914                 None
# 15915     1 previous owner
# 15916     1 previous owner
# 15917                 None
# 15918     1 previous owner
# Name: prev_owner, Length: 15919, dtype: object

# %%
df['prev_owner'].value_counts(dropna=False)
# Out:
# 1 previous owner     8294
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
df['Previous Owners'].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# \n1\n                                                                                        8101
# NaN                                                                                          6640
# \n2\n                                                                                         766
# \n0\n                                                                                         163
# ...

# %% [markdown]
# ### 'Previous Owners'¶

# %%
df['Previous Owners'].str.strip("\n") ##Normalde strip string in attribite dir
# Out:
# 0          2
# 1        NaN
# 2          1
# 3          1
# 4          1
#         ...
# 15914    NaN
# 15915    NaN
# 15916    NaN
# 15917    NaN
# 15918      1
# Name: Previous Owners, Length: 15919, dtype: object

# %%
df['Previous Owners'].str.strip("\n").value_counts(dropna=False) 
### Strip yapinca NAN degeri vermis NAN degeri yukseldi 6870 mesela \n1 leri nan okumus baktik
# Out:
# 1      8101
# NaN    6870
# 2       766
# 0       163
# 3        17
# 4         2
# Name: Previous Owners, dtype: int64

# %%
df['Previous Owners'].str[0] 

# Listenin str[0] ile ilk eleman geldi.listenin icinde ise ilk eleman geldi disinda ise new line geldi.
# Out:
# 0           \n
# 1          NaN
# 2           \n
# 3           \n
# 4           \n
#          ...
# 15914      NaN
# 15915    \n1\n
# 15916    \n1\n
# 15917      NaN
# 15918       \n
# Name: Previous Owners, Length: 15919, dtype: object

# %%
df['Previous Owners'].str[0].str[1]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 15914    NaN
# 15915      1
# 15916      1
# 15917    NaN
# 15918    NaN
# Name: Previous Owners, Length: 15919, dtype: object

# %%
df['Previous Owners'].str[0].str[1].value_counts(dropna=False)
# Out:
# NaN    15689
# 1        193
# 0         25
# 2         12
# Name: Previous Owners, dtype: int64

# %% [markdown]
# ###### There are 230 new values which are not visible in previous format.
# 1 → 193
#
# 0 → 25
#
# 2 → 12

# %%
df['Previous Owner1']= df['Previous Owners'].str[0].str[1]
df['Previous Owner1']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 15914    NaN
# 15915      1
# 15916      1
# 15917    NaN
# 15918    NaN
# Name: Previous Owner1, Length: 15919, dtype: object

# %%
df['Previous_Owner']= df['Previous Owners'].str.strip("\n")
df['Previous_Owner']
# Out:
# 0          2
# 1        NaN
# 2          1
# 3          1
# 4          1
#         ...
# 15914    NaN
# 15915    NaN
# 15916    NaN
# 15917    NaN
# 15918      1
# Name: Previous_Owner, Length: 15919, dtype: object

# %%
df.Previous_Owner.fillna(df.Previous_Owner1, inplace=True)
df.Previous_Owner.value_counts(dropna=False) 

#birbirine karsilik gelen indexler birbirini dolduracak 230 value var gerisi NAN ve NAN lar dolacak.
# Out:
# 1      8101
# NaN    6870
# 2       766
# 0       163
# 3        17
# 4         2
# Name: Previous_Owner, dtype: int64

# %% [markdown]
# ### We select "Previous_Owner"
# ## oransal olarak doldurmak istersek bfill ile

# %%
df.Previous_Owner.fillna(method="bfill", inplace=True)

# %%
df["Previous_Owner"].value_counts(dropna = False)
# Out:
# 1    14252
# 2     1169
# 0      454
# 3       42
# 4        2
# Name: Previous_Owner, dtype: int64

# %% [markdown]
# ### "prev_owner"

# %%
df.prev_owner.value_counts(dropna = False)
# Out:
# 1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
df["prev_owner"] = df["prev_owner"].str.replace(" previous owner", "").str.replace("s", "")

# %%
df.prev_owner.value_counts(dropna = False)
# Out:
# 1      8294
# NaN    6828
# 2       778
# 3        17
# 4         2
# Name: prev_owner, dtype: int64

# %%
df.Previous owner.value_counts(dropna=False) ##Karsilastirdigimizda degerleri previous owner daha etkili

# %%
df["prev_owner"].fillna(method='bfill', inplace=True)

# %%
df.prev_owner.value_counts(dropna = False)
# Out:
# 1    14692
# 2     1187
# 3       38
# 4        2
# Name: prev_owner, dtype: int64

# %%
df["Previous_Owner"].value_counts()
# Out:
# 1    14252
# 2     1169
# 0      454
# 3       42
# 4        2
# Name: Previous_Owner, dtype: int64

# %% [markdown]
# ### we can drop "prev_ovner", "Weight", "Non-smoking Vehicle".

# %%
drop_list2 = ["prev_ovner", "Weight", "Non-smoking Vehicle"]

# %%
df.drop(drop_list2, axis=1, inplace=True)

# %%
def fill_most(oto, group_col, col_name):
    for group in list(oto[group_col].unique()) :
        grp_inx = list(oto[oto[group_col] == group][col_name].index)
        oto[col_name].iloc[grp_inx] = oto[col_name].iloc[grp_inx].fillna(oto[oto[group_col] == group][col_name].mode()[0])

# %%
#fill_most(df, "make_model", "body_type")

# %%
#fill_most(df, "make_model", "Extras")

# %%
#fill_most(df, "make_model", "Comfort&Convenience")

# %%
df["make_model"].unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %%
### Marka model uzerinden giderek en cok ayri ayri tekrar eden deger ile doldurmak mantikli burda ve fonk yazdik.

# %%
### OTHER METHODS
def fillna(col1,col2):
    s=rw[rw.make_model==col1][col2]
    g = list(s.items())
    idx = [i for i,j in g if pd.isnull(j)]
    d = rw[col2]
    for i in range(len(idx)) :
        d[idx[i]] = s.mode()[0]
    return rw[col2].isnull().sum()


#car['body_type2'] = car['body_type'].fillna(car.groupby('model1')['body_type'].apply(lambda x: x.fillna(x.mode()[0])))

# %%
df["body_type"].iloc[grp_inx]
# Out:
# 2615      Convertible
# 2616           Sedans
# 2617           Sedans
# 2618           Sedans
# 2619           Sedans
#             ...
# 5707           Sedans
# 5708           Sedans
# 5709    Station wagon
# 5710           Sedans
# 5711           Sedans
# Name: body_type, Length: 3097, dtype: object

# %%
df[df["make_model"] == "Audi A3"]["body_type"]
# Out:
# 2615      Convertible
# 2616           Sedans
# 2617           Sedans
# 2618           Sedans
# 2619           Sedans
#             ...
# 5707           Sedans
# 5708           Sedans
# 5709    Station wagon
# 5710           Sedans
# 5711           Sedans
# Name: body_type, Length: 3097, dtype: object

# %%
grp_inx = list(oto[oto["make_model"] == "Audi A3"]["body_type"].index)

# %%
grp_inx

# %%
df["body_type"].iloc[2680]
# Out:
# 'Sedans'

# %%
#df[col_name].iloc[grp_inx] = df[col_name].iloc[grp_inx].fillna()

# %%
df[df["make_model"] == "Audi A3"]["body_type"].fillna("Sedans")
# Out:
# 2615      Convertible
# 2616           Sedans
# 2617           Sedans
# 2618           Sedans
# 2619           Sedans
#             ...
# 5707           Sedans
# 5708           Sedans
# 5709    Station wagon
# 5710           Sedans
# 5711           Sedans
# Name: body_type, Length: 3097, dtype: object

# %%
oto[oto["make_model"] == "Audi A3"]["body_type"].mode()[0]

# %%
df[df["make_model"] == "Renault Espace"]["body_type"].mode()[0]
# Out:
# 'Van'

# %% [markdown]
# ### body_type'¶

# %%
df["body_type"].value_counts(dropna = False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.groupby("make_model")["body_type"].value_counts(dropna = False)
# Out:
# make_model      body_type
# Audi A1         Sedans           1538
#                 Compact          1039
#                 Station wagon      21
#                 Other              13
#                 Coupe               2
#                 Van                 1
# Audi A2         Off-Road            1
# Audi A3         Sedans           2598
#                 Station wagon     282
#                 Compact           182
#                 Other              16
#                 Convertible         8
#                 NaN                 7
#                 Coupe               4
# Opel Astra      Station wagon    1211
#                 Sedans           1053
#                 Compact           185
#                 Other              67
#                 NaN                 7
#                 Coupe               2
#                 Off-Road            1
# Opel Corsa      Compact          1230
#                 Sedans            875
#                 Other              87
# ...

# %%
fill_most(df, "make_model","body_type")

# %%
df.body_type.value_counts(dropna = False)
# Out:
# Sedans           7925
# Station wagon    3563
# Compact          3155
# Van               809
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %% [markdown]
# ### ``"Body"``

# %%
df["Body"].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Sedans, \n]           7903
# [\n, Station wagon, \n]    3553
# [\n, Compact, \n]          3153
# [\n, Van, \n]               783
# [\n, Other, \n]             290
# [\n, Transporter, \n]        88
# NaN                          60
# [\n, Off-Road, \n]           56
# [\n, Coupe, \n]              25
# [\n, Convertible, \n]         8
# Name: Body, dtype: int64

# %% [markdown]
# ### "Body" deserves to be dropped¶

# %%
oto.drop("Body", axis = 1, inplace = True)

# %%
fill_most(df, "make_model","Extras")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Extras'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-619c74ba4ff0> in <module>
# ----> 1 fill_most(df, "make_model","Extras")
# ...

# %%
def fill_most(df, "make_model","Comfort&Convenience")
# Out:
#   File "<ipython-input-64-a67cc44c0354>", line 1
#     def fill_most(df, "make_model","Comfort&Convenience")
#                                  ^
# SyntaxError: invalid syntax

# %%
grp_inx = list(df[df["make_model"]=="Audi A3"]["body_type"].index)

# %%
df["body_type"].iloc[grp_inx]
# Out:
# 2615      Convertible
# 2616           Sedans
# 2617           Sedans
# 2618           Sedans
# 2619           Sedans
#             ...
# 5707           Sedans
# 5708           Sedans
# 5709    Station wagon
# 5710           Sedans
# 5711           Sedans
# Name: body_type, Length: 3097, dtype: object

# %%
df["make_model"].unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %%
for group in list(df["group_col"].unique()):
# Out:
#   File "<ipython-input-25-e7abf04bdeee>", line 1
#     for group in list(df["group_col"].unique())
#                                                ^
# SyntaxError: invalid syntax

# %%
#df[df["gruop_col"]==group]["col_name"].index

# %%
#df[col_name].iloc[grp_inx]

# %%
df["body_type"].iloc[2615] ## Doluymus bu index NAN bulup onu bulmaya calisicaz, burada her bir NAN a Sedan doldurucaz simdi
# Out:
# 'Convertible'

# %%
grp_inx = list(df[df["group_col"]=="group"]["col_name"].index)

grp_inx = list(df[df["make_model"]=="Audi A3"]["body_type"].index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group_col'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-d6ed3228a24d> in <module>
# ...

# %%
df["body_type"].iloc[index] = df["body_type"].iloc[index].fillna
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-2c7612ad44c8> in <module>
# ----> 1 df["body_type"].iloc[index] = df["body_type"].iloc[index].fillna
#
# NameError: name 'index' is not defined

# %%
#df[col_name].iloc[grp_inx]
df['body_type'].iloc[2680] = "Sedan"

# %%
df['body_type'].iloc[2680]
# Out:
# 'Sedans'

# %%
df[col_name].iloc[grp_inx] = df[col_name].iloc[grp_inx].fillna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5a1504254bd6> in <module>
# ----> 1 oto[col_name].iloc[grp_inx] = oto[col_name].iloc[grp_inx].fillna()
#
# NameError: name 'col_name' is not defined

# %%
oto["make_model"].unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %%
for group in list(oto["make_model"].unique()):
# Out:
#   File "<ipython-input-22-f56f733922ed>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
oto[oto["make_model"]=="Audi A3"]["Body"]
# Out:
# 2615      [\n, Convertible, \n]
# 2616           [\n, Sedans, \n]
# 2617           [\n, Sedans, \n]
# 2618           [\n, Sedans, \n]
# 2619           [\n, Sedans, \n]
#                  ...
# 5707           [\n, Sedans, \n]
# 5708           [\n, Sedans, \n]
# 5709    [\n, Station wagon, \n]
# 5710           [\n, Sedans, \n]
# 5711           [\n, Sedans, \n]
# Name: Body, Length: 3097, dtype: object

# %%
#oto[oto["make_model"]=="Audi A3"]["body_type"].fillna("Sedan")

# %%
df[df["make_model"]=="Audi A3"]["body_type"].mode()[0]
# Out:
# 'Sedans'

# %%
df[df["make_model"]=="Audi A1"]["body_type"].mode()[0]
# Out:
# 'Sedans'

# %%
oto[oto["make_model"]=="Renault Espace"]["body_type"].mode()[0]
# Out:
# 'Van'

# %%
df[df["make_model"]=="Audi A3"]["Body"].index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-86db3e3c12ac> in <module>
# ----> 1 oto[oto["make_model"]=="Audi A3"]["Body"].index
#
# NameError: name 'oto' is not defined

# %%
grp_inx = list(df[df["make_model"]=="Audi A3"]["Body"].index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-a34e7d98eadc> in <module>
# ----> 1 grp_inx = list(oto[oto["make_model"]=="Audi A3"]["Body"].index)
#
# NameError: name 'oto' is not defined

# %%
grp_inx = list(df[df["group_col"]=="Audi A3"]["Body"].index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group_col'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-fb293d2217a8> in <module>
# ...

# %% [markdown]
# ##
# ### Body type ile kasilastirildiginda body dusurulebilir.

# %%
#Nan_to_list(oto,"Body")
#unique_values(oto, Body)

# %%
df['body_type'].value_counts(dropna=False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.groupby("make_model")['body_type'].value_counts(dropna=False)
# Out:
# make_model      body_type
# Audi A1         Sedans           1538
#                 Compact          1039
#                 Station wagon      21
#                 Other              13
#                 Coupe               2
#                 Van                 1
# Audi A2         Off-Road            1
# Audi A3         Sedans           2598
#                 Station wagon     282
#                 Compact           182
#                 Other              16
#                 Convertible         8
#                 NaN                 7
#                 Coupe               4
# Opel Astra      Station wagon    1211
#                 Sedans           1053
#                 Compact           185
#                 Other              67
#                 NaN                 7
#                 Coupe               2
#                 Off-Road            1
# Opel Corsa      Compact          1230
#                 Sedans            875
#                 Other              87
# ...

# %%
fill_most(df, "make_model", "body_type")

# %%
df.body_type.value_counts(dropna=False) #Nan lar dolmus bos yok
# Out:
# Sedans           7925
# Station wagon    3563
# Compact          3155
# Van               809
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %% [markdown]
# # Body

# %%
df['Body'].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Sedans, \n]           7903
# [\n, Station wagon, \n]    3553
# [\n, Compact, \n]          3153
# [\n, Van, \n]               783
# [\n, Other, \n]             290
# [\n, Transporter, \n]        88
# NaN                          60
# [\n, Off-Road, \n]           56
# [\n, Coupe, \n]              25
# [\n, Convertible, \n]         8
# Name: Body, dtype: int64

# %%
df.drop("Body", axis=1, inplace=True)

# %% [markdown]
# ### Inspection new
#
# # It has %77 of missing value. For now, lets's leave it as it is. We can take a look at it again later.

# %%
df['Inspection new'].isnull().sum()/len(df["Inspection new"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Inspection new'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-257-e24550b7f20f> in <module>
# ...

# %%
Inspection new

# %%
df['Inspection new'].str[0].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Inspection new'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-258-7e69127ba7cd> in <module>
# ...

# %%
df['Inspection new'].str[0].str.contains('\n', na=False)

# %%
True*1
# Out:
# 1

# %%
False*1
# Out:
# 0

# %%
df['Inspection_New_Bool']= df['Inspection new'].str[0].str.contains('\n', na=False)*1

# %%
df['Inspection_New_Bool'].str[0].value_counts(dropna=False)

# %% [markdown]
# ### next_inspection

# %%
df['Next Inspection'].isnull().sum()/len(df[value_counts(['Next Inspection'])
# Out:
#   File "<ipython-input-261-679f3198949d>", line 1
#     df['Next Inspection'].isnull().sum()/len(df[value_counts(['Next Inspection'])
#                                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
a= ["I am a list"]

# %%
type(a)==list
# Out:
# True

# %%
"".join(a).strip()
# Out:
# 'I am a list'

# %%
df['Next Inspection'].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# NaN                                                                                                12384
# \n04/2022\n                                                                                           62
# \n03/2021\n                                                                                           38
# \n03/2022\n                                                                                           36
# ...

# %%
#join list yapabiliriz string olur

#df["Next Inspection"] = [item[0] if type(item) == list else item for item in df["Next Inspection"]]

# %% [markdown]
# next inspection icin yapilan islem: liste icindekileri disari cikarip string yapmak, zaten string olanlari korumak. sonucta degerlerin hepsini temiz string yapmak

# %%
"a b c".strip()
# Out:
# 'a b c'

# %%
''.join().strip()

# %%
''.join("   benim adim joseph    ").strip() ### Strip ile jenerik duzenledik bosluklari atip duzgun halde veriyor.
# Out:
# 'benim adim joseph'

# %%
''.join(["benim adim joseph"]) # liste olarak atilan degeri disari string olarak cikarir JOIN.
# Out:
# 'benim adim joseph'

# %%
''.join().strip() if type(item) == list else item for item in df ["Next Inspection"]
#bastan ve sondan striplesin benim item im listenin icerisinde ise

# %%
df["Next Inspection"].head()
# Out:
# 0    [\n06/2021\n, \n99 g CO2/km (comb)\n]
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# Name: Next Inspection, dtype: object

# %%
# type list ise yukaridaki kurali uygulayacak nan ayni kalaacak string ise else yani oldugu gibi birak.

# %%
z =[ ''.join(item).strip() if type(item) == list else item for item in df ["Next Inspection"]]
#ternary condition
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Next Inspection'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-266-39233384ce5f> in <module>
# ...

# %%
nxtins = ["".join(item).strip() if type(item) == list else item for item in oto["Next Inspection"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-272-df6ef719ed9c> in <module>
# ----> 1 nxtins = ["".join(item).strip() if type(item) == list else item for item in oto["Next Inspection"]]
#
# NameError: name 'oto' is not defined

# %%
## extract bize dataframe dondurur.
df["next_inspection"] = df.next_inspection.str.extract("\d\d/\d\d\d\d")

# %%
df.next_inspection.value_counts(dropna=False)

# %%
df.next_inspection = pd.to_datetime(df.next_inspection, format = "%m%Y") #formati boyle algila dedik

# %%
df.next_inspection.value_counts(dropna=False)

# %% [markdown]
# ### "Paint Type"

# %%
df['Paint Type'].isnull().sum()/len(df['Paint Type'])*100
# Out:
# 36.25855895470821

# %%
df.Paint Type.value_counts(dropna=False)
# Out:
#   File "<ipython-input-269-673e5d684637>", line 1
#     df.Paint Type.value_counts(dropna=False)
#                 ^
# SyntaxError: invalid syntax

# %%
df['Paint Type'].str[0].str.strip("\n").value_counts(dropna=False)
# Out:
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: Paint Type, dtype: int64

# %%
df['paint_type'].

# %% [markdown]
# #### "Country version"

# %%
df['Country version'].isnull().sum()/len(df[value_counts(['Country version'])
# Out:
#   File "<ipython-input-273-8d154b5d60af>", line 1
#     df['Country version'].isnull().sum()/len(df[value_counts(['Country version'])
#                                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
value_counts

# %%
str[0]str.strip("\n")

# %% [markdown]
# ## "Cylinders"

# %%
str[0].str.strip("\n")

# %%
df["Cylinders"]

# %% [markdown]
# ### 'Emission Label'

# %%
df['Emission Label'].isnull().sum()/len(['Emission Label'])

# %%
df['Emission Label'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Emission Label'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-276-beac17ead1a4> in <module>
# ...

# %%
str[0].str.strip(\n)

# %%
df["emission_label"] = df["Emission Label"].str[0].str.strip("\n")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Emission Label'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-278-5b6419371e31> in <module>
# ...

# %%
df.emission_label.value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-277-f4c8512cf23e> in <module>
# ----> 1 df.emission_label.value_counts(dropna=False)
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'emission_label'

# %% [markdown]
# https://stackoverflow.com/questions/716477/join-list-of-lists-in-python
# liste icinden liste cikarma

# %% [markdown]
# ##### New Column Name Fonk
#
# def explosion(df,column,new_col_name):
#     df_exploded = df[old_col_name].apply(pd.Series)
#     df_exploded = df_exploded.rename(columns = lambda x : new_col_name + str(x))
#     df = pd.concat([df[:], df_exploded[:]], axis=1)
#     return df

# %%
df["next_inspection"]= pd.DataFrame(z)
df["next_inspection"]
# Out:
# 0         06/2021\n\n99 g CO2/km (comb)
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#                       ...
# 15914                               NaN
# 15915    01/2022\n\n168 g CO2/km (comb)
# 15916                               NaN
# 15917                               NaN
# 15918                               NaN
# Name: next_inspection, Length: 15919, dtype: object

# %% [markdown]
# ### "Full Service"

# %%
df["Full Service"].isnull().sum()/len(["Full Service"])*100
# Out:
# 770400.0

# %%
df["Full Service"].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# NaN                                                                                           7704
# [\n, \n, \n4 (Green)\n]                                                                       2235
# [\n, \n, \nEuro 6\n]                                                                          2097
# [\n, \n]                                                                                      1702
# ...

# %%
list(df["Full Service"].value_counts(dropna=False).index) ## daha ayrintili bakiyoruz list ile tek tek.
##Cok karisik bir veri yeniden istenebilir daha duzgun cekebilme, isteyebilme imkanina bakmali duzelmesi zor, karisik.
# Out:
# [nan,
#  ['\n', '\n', '\n4 (Green)\n'],
#  ['\n', '\n', '\nEuro 6\n'],
#  ['\n', '\n'],
#  ['\n', '\n', '\nEuro 6d-TEMP\n'],
#  '\n',
#  ['\n', '\n', '\n120 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n126 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n104 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n97 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n124 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n99 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n128 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n119 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n140 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n106 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n92 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n107 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n114 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n102 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n103 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n1 (No sticker)\n'],
#  ['\n', '\n', '\nEuro 6c\n'],
#  ['\n', '\n', '\n139 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n117 g CO2/km (comb)\n'],
#  ['\n', '\n', '\n127 g CO2/km (comb)\n'],
# ...

# %% [markdown]
# ### "Comfort & Convenience"

# %%
df["\nComfort & Convenience\n"]
# Out:
# 0                                                                                                                                                                                               [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, Hill Holder, Leather steering wheel, Light sensor, Multi-function steering wheel, Navigation system, Park Distance Control, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system]
# ...

# %%
df["\nComfort & Convenience\n"].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# NaN                                                                                                                                                                                                                                                                                                                                                                     920
# ...

# %%
df["\nComfort & Convenience\n"].value_counts(dropna=False).head(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ...

# %%
df["\nComfort & Convenience\n"].value_counts(dropna=False).tail(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ...

# %%
#set() unique yapilari veriyor sadece tek olanlari aliyoruz faka NAN larda problem oluyor NAN lari bos liste yapmali
ubdate(["a", "b", "c", "d"])

# %%
#uni= set()
#uni.update([np.nan])
#uni.update(["a", "b", "a"])
#list(uni)
# Out:
# ['b', 'a']

# %%
uni= set()
uni.update([])
uni.update(["a", "b", "a"])
list(uni)
# Out:
# ['b', 'a']

# %%
#unique valu ler bu kumede birekecek bu fonk ile.
def unique_values():
    unique_vals = set()
    for rows in data [column_names]
        unique_vals.update(rows)
    return list(unique_vals)

# %%
nans = df['\nComfort & Convenience\n'].isnull## null lari True yapiyor.

# %%
df.loc[nans, "\nComfort & Convenience\n"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-291-347b0e78706f> in <module>
# ----> 1 df.loc[nans, "\nComfort & Convenience\n"]
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1753     def __getitem__(self, key):
#    1754         if type(key) is tuple:
# -> 1755             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1756             if self._is_scalar_access(key):
#    1757                 try:
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexing.py in <genexpr>(.0)
#    1753     def __getitem__(self, key):
#    1754         if type(key) is tuple:
# -> 1755             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1756             if self._is_scalar_access(key):
#    1757                 try:
#
# ...

# %%
##Nan lari listeye cevirelim
def Nan_to_list(data, column_name):
    NaN_rows = data[column_name].isnull()
    data.loc[NaN_rows, column_name] = data.loc[NaN_rows, column_name].apply(lambda x : [])

# %%
Nan_to_list(df, "\nComfort & Convenience\n")
unique_values(df,"\nComfort & Convenience\n")

# %%
b = ["ben sen o"]

# %%
nxtins_list =[','.join(item).strip() if type(item) == list else item for item in df ["\nComfort & Convenience\n"]]
nxtins_list
# Out:
# ['Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system',
#  'Air conditioning,Automatic climate control,Hill Holder,Leather steering wheel,Lumbar support,Parking assist system sensors rear,Power windows,Start-stop system,Tinted windows',
#  'Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Seat heating,Start-stop system',
# ...

# %%
df["Comfort&Convenience"]=pd.DataFrame(nxtins_list)

# %%
df["Comfort&Convenience"].value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                   920
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                    216
# ...

# %%
## Burda NAn lar gitti onlari geri getirmemeiz lazim bos string halindeler su anda

# %%
df["Comfort&Convenience"].isnull().sum()

# %%
a = [np.nan if df["Comfort&Convenience"].iloc[i]== "" else df["Comfort&Convenience"].iloc[i] for i in range(len)

# %%
df["Comfort&Convenience"]=a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-293-9d0be1253c8e> in <module>
# ----> 1 df["Comfort&Convenience"]=a
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# ...

# %%
df["Comfort&Convenience"].value_counts(drop=False) ### burda NAN lar da geldi ve hepsi virgulle ayrilmis duzgun oldu.

# %%
fill_most(df, "make_model", ""Comfort&Convenience"")

# %%
df["eskisine bak"][0]

# %%
df['Comfort&Convenience'][0]

# %%
"Windshield" in df['Comfort&Convenience'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Comfort&Convenience'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-292-321298dc7097> in <module>
# ...

# %%
df['Comfort&Convenience'].str.get_dummies(sep=",")

# %%
df[df["Comfort&Convenience"]== pd.DataFrame(nxtins_list)

# %% [markdown]
# ##### Other Method
#
# def list_to_String(x):
#     a = []
#     if (isinstance(x, (list))):
#         for i in x:
#             if (isinstance(i, (float, int, str))) and (i != "") and (i != "\n"):
#                           a.append(i)
#     elif np.isnan(x):
#         return np.NaN
#     else:
#         raise Exception ("Sorry, some values are not list")
#     a= " ".join(a)
#     return re.sub('\n', "", a)

# %%
df["Nr. of Doors"].str[0].str[1]
#df["Nr. of Doors"].str[0].strip("\n")
# Out:
# 0        5
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    5
# 15917    5
# 15918    5
# Name: Nr. of Doors, Length: 15919, dtype: object

# %%
df['hp']
# Out:
# 0         66 kW
# 1        141 kW
# 2         85 kW
# 3         66 kW
# 4         66 kW
#           ...
# 15914    147 kW
# 15915    165 kW
# 15916    146 kW
# 15917    147 kW
# 15918    165 kW
# Name: hp, Length: 15919, dtype: object

# %%
for i in range(len(df['hp'])):
    df['hp'][i]= re.sub('[^0-9]','',df['hp'][i])
# Out:
# C:\Users\ilkca\anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.hp
# Out:
# 0         66
# 1        141
# 2         85
# 3         66
# 4         66
#         ...
# 15914    147
# 15915    165
# 15916    146
# 15917    147
# 15918    165
# Name: hp, Length: 15919, dtype: object

# %%
df["First Registration"]
# Out:
# 0        [\n, 2016, \n]
# 1        [\n, 2017, \n]
# 2        [\n, 2016, \n]
# 3        [\n, 2016, \n]
# 4        [\n, 2016, \n]
#               ...
# 15914               NaN
# 15915    [\n, 2019, \n]
# 15916    [\n, 2019, \n]
# 15917    [\n, 2019, \n]
# 15918    [\n, 2019, \n]
# Name: First Registration, Length: 15919, dtype: object

# %%
pd.read_csv("ornekcsv.csv", sep = ";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-258-514693d0b14d> in <module>
# ----> 1 pd.read_csv("ornekcsv.csv", sep = ";")
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df["First Registration"].strip("\n")

# %%
def n_sil('First Registration'):
    for i in range(0, len(['First Registration'])):
        if isinstance(First Registration[i], list):
            for a in First Registration[i]:
                if a == "\n":
                    First Registration[i].remove(a)
                elif "\n" in a:
                    First Registration[i].remove(a)
                    b = a.replace("\n", "")
                    First Registration[i].append(b)
        elif isinstance(First Registration[i], str):
            First Registration[i] = First Registration[i].replace("\n", "")
# Out:
#   File "<ipython-input-259-7bc62bdf8fc2>", line 1
#     def n_sil('First Registration'):
#                                  ^
# SyntaxError: invalid syntax

# %%
def n_sil('Displacement'):
    for i in range(0, len(['Displacement'])):
        if isinstance(Displacement[i], list):
# Out:
#   File "<ipython-input-338-3ac7a8f4b225>", line 1
#     def n_sil('Displacement'):
#                            ^
# SyntaxError: invalid syntax

# %%
df["Displacement"].iloc[0][0]
# Out:
# '\n1,422 cc\n'

# %%
a= str(df["Displacement"].iloc[0][0])
a
# Out:
# '\n1,422 cc\n'

# %%
a[0].apply(lambda x: x.split("\n")[0]).value_counts().head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-355-299a26fcb8f0> in <module>
# ----> 1 a[0].apply(lambda x: x.split("\n")[0]).value_counts().head(5)
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
df["Displacement"].str[0]
# Out:
# 0        \n1,422 cc\n
# 1        \n1,798 cc\n
# 2        \n1,598 cc\n
# 3        \n1,422 cc\n
# 4        \n1,422 cc\n
#              ...
# 15914    \n1,997 cc\n
# 15915    \n1,798 cc\n
# 15916    \n1,997 cc\n
# 15917    \n1,997 cc\n
# 15918    \n1,798 cc\n
# Name: Displacement, Length: 15919, dtype: object

# %%
df["Displacement"].str[0].strip("\n")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-349-6df87794e427> in <module>
# ----> 1 df["Displacement"].str[0].strip("\n")
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
 for i in range(len(df["Displacement"])):
    a = re.search('(\d*.\d*)',str(df.Displacement[i][0]))
    z = print(a.group())
z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-300-06ae9650fa14> in <module>
#       1 for i in range(len(df["Displacement"])):
# ----> 2    a = re.search('(\d*.\d*)',str(df.Displacement[i][0]))
#       3    z = print(a.group())
#       4 z
#
# NameError: name 're' is not defined

# %%
k= []
k1 = k.append(print(a.group())
k1
# Out:
#   File "<ipython-input-326-6d161e5da268>", line 3
#     k1
#      ^
# SyntaxError: invalid syntax

# %%
print(a.group())
# Out:
# 1,598

# %%
output = re.search('(\d*.\d*)', str(df.Displacement[1][0]))
print(output.group())
# Out:
# 1,798

# %%
import re
import pandas as pd

# %%
a = str(df.Displacement[0][0])
a
# Out:
# '\n1,422 cc\n'

# %%
a = str(df.Displacement[1][0])
a
# Out:
# '\n1,798 cc\n'

# %%
output = re.search('(\d*.\d*)', str(df.Displacement[1][0]))
print(output.group())
# Out:
# 1,798

# %%
map(lambda x: x * 2 , my_list)

# %%
df.Displacement.apply(lambda x: re.search('(\d*.\d*)', str(df.Displacement[x][0]),df.Displacement)
# Out:
#   File "<ipython-input-175-625385d80644>", line 1
#     df.Displacement.apply(lambda x: re.search('(\d*.\d*)', str(df.Displacement[x][0]),df.Displacement)
#                                                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
[for i in re.search('(\d*.\d*)', str(df.Displacement[i][0]):
   result
# Out:
#   File "<ipython-input-168-751ecd0ff662>", line 1
#     [for i in re.search('(\d*.\d*)', str(df.Displacement[i][0]):
#        ^
# SyntaxError: invalid syntax

# %%
df["Displacement"].str.extract(pat = '(/d*)')
# Out:
#          0
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914  NaN
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
# [15919 rows x 1 columns]

# %%
def Clean_data(a): 
    # Search for opening bracket in the name followed by 
    # any characters repeated any number of times 
    if re.search('\,.*', a): 
  
        # Extract the position of beginning of pattern 
        pos = re.search('\,.*', a).start() 
  
        # return the cleaned name 
        return a[:pos] 
  
    else: 
        # if clean up needed return the same name 
        return a 
          
# Updated the city columns 
df['Displacement'] = df['Displacement'].apply(Clean_data) 
  
# Print the updated dataframe 
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-7574349acf30> in <module>
#      15
#      16 # Updated the city columns
# ---> 17 df['Displacement'] = df['Displacement'].apply(Clean_data)
#      18
#      19 # Print the updated dataframe
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-153-7574349acf30> in Clean_data(a)
#       2     # Search for opening bracket in the name followed by
#       3     # any characters repeated any number of times
# ...

# %%
s = pd.Series(df["Displacement"])
s
# Out:
# 0        [\n1,422 cc\n]
# 1        [\n1,798 cc\n]
# 2        [\n1,598 cc\n]
# 3        [\n1,422 cc\n]
# 4        [\n1,422 cc\n]
#               ...
# 15914    [\n1,997 cc\n]
# 15915    [\n1,798 cc\n]
# 15916    [\n1,997 cc\n]
# 15917    [\n1,997 cc\n]
# 15918    [\n1,798 cc\n]
# Name: Displacement, Length: 15919, dtype: object

# %%
df["Displacement"][150]
# Out:
# ['\n999 cc\n']

# %%
re.findall("\d*.\d*", a)
# Out:
# ['1,422', ' ', 'c', 'c']

# %%
output = re.search('(\d*.\d*)', a)
print(output.group())
# Out:
# 1,422

# %%
total_list = []
for i in range(len(df.Displacement)):
       for  (re.search('(\d*.\d*)', df.Displacement[i])) in df.Displacement[i]:
        total_list.append(re.search('(\d*.\d*)', df.Displacement[i]))
# Out:
#   File "<ipython-input-5-40e6d5695c70>", line 3
#     for  (re.search('(\d*.\d*)', df.Displacement[i])) in df.Displacement[i]:
#         ^
# SyntaxError: can't assign to function call

# %%
a.str.extract('(\d).+(\d*)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-147-3e2704cfb6f4> in <module>
# ----> 1 a.str.extract('(\d).+(\d*)')
#
# AttributeError: 'str' object has no attribute 'str'

# %%
output.str.split(",")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-4d20e2bfca66> in <module>
# ----> 1 output.str.split(",")
#
# AttributeError: 're.Match' object has no attribute 'str'

# %%
(output.group()).apply(lambda x: x.split(","))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-9ed78c9b95f6> in <module>
# ----> 1 (output.group()).apply(lambda x: x.split(","))
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
(str(df.Displacement[0][0])).apply(lambda x: x.split("@")[1]).value_counts().head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-63e99c4dba70> in <module>
# ----> 1 (str(df.Displacement[0][0])).apply(lambda x: x.split("@")[1]).value_counts().head(5)
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
df["Displacement"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-2e2cdab42e7c> in <module>
# ----> 1 df["Displacement"].astype(int)
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
# ...

# %%
#df["Displacement"].str[0].str[1]
df["Displacement"].str[0].strip("\n")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-ab4fdaff7e80> in <module>
#       1 #df["Displacement"].str[0].str[1]
# ----> 2 df["Displacement"].str[0].strip("\n")
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
df['CO2 Emission1'].apply(lambda x : x if pd.isna(x) else x.split(" ")[0])
